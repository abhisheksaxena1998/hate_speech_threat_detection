# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".7"})

d1=pd.read_csv("input2_threat.csv",encoding="latin1")
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0           621             621   CluelessTories
# 1              1          4385            4385      goodnitebob
# 2              2          8201            8201     Mr_P_Panther
# 3              3          4562            4562    JeanneBartram
# 4              4          8161            8161    DeannaNolan17
# ...          ...           ...             ...              ...
# 1010        1010          2874            2874      FrankieMac9
# 1011        1011          5500            5500  RhubarbVaselino
# 1012        1012          7399            7399  myerschrismyer1
# 1013        1013          2542            2542  GeordieJoeHardy
# 1014        1014          8235            8235    allanholloway
#
#                                                username              user_id  \
# 0             Citizen Smith - #FBPE5000#RevokeArticle50             44657626
# 1                                           goodnitebob  1064586673722454017
# 2                                      The Pink Panther   944224944170430464
# 3     Spider woman ÃÂ°ÃÂÃÂÃÂ·ÃÂ¯ÃÂ¸ÃÂ #Rev...            555337622
# 4                                          Deanna Nolan  1145426486905712650
# ...                                                 ...                  ...
# 1010                                       Frankie Mac9           4824152675
# 1011                                   Rhubarb Vaselino   849759279271866368
# 1012                                        Chris Myers   865262041103302656
# 1013                 Joe Hardy ÃÂ¢ÃÂÃÂ«ÃÂ¯ÃÂ¸ÃÂ   806113446546853888
# 1014                                           Arthur_S            129594482
#
#                  tweet_id                                    tweet_url  \
# 0     1142693298274017281   /CluelessTories/status/1142693298274017281
# 1     1162654770617868288      /goodnitebob/status/1162654770617868288
# 2     1179437737029574656     /Mr_P_Panther/status/1179437737029574656
# 3     1189669117797777410    /JeanneBartram/status/1189669117797777410
# 4     1179471663311798273    /DeannaNolan17/status/1179471663311798273
# ...                   ...                                          ...
# 1010  1133830545048264704      /FrankieMac9/status/1133830545048264704
# 1011  1148665305150963712  /RhubarbVaselino/status/1148665305150963712
# 1012  1152181227144785920  /myerschrismyer1/status/1152181227144785920
# 1013  1136197416116543488  /GeordieJoeHardy/status/1136197416116543488
# 1014  1179395666717609986    /allanholloway/status/1179395666717609986
#
#                 timestamp  timestamp_epochs  ... video_url likes retweets  \
# 0     2019-06-23 07:18:07        1561274287  ...       NaN    11        0
# 1     2019-08-17 09:17:53        1566033473  ...       NaN     1        0
# 2     2019-10-02 16:47:24        1570034844  ...       NaN     0        0
# 3     2019-10-30 22:23:15        1572474195  ...       NaN     0        0
# 4     2019-10-02 19:02:12        1570042932  ...       NaN     2        3
# ...                   ...               ...  ...       ...   ...      ...
# 1010  2019-05-29 20:20:42        1559161242  ...       NaN     0        0
# 1011  2019-07-09 18:48:44        1562698124  ...       NaN     1        0
# 1012  2019-07-19 11:39:45        1563536385  ...       NaN     0        0
# 1013  2019-06-05 09:05:48        1559725548  ...       NaN     0        0
# 1014  2019-10-02 14:00:13        1570024813  ...       NaN     0        0
#
#      replies  is_replied is_reply_to  parent_tweet_id  \
# 0          0       False        True     1.142680e+18
# 1          0       False        True     1.162394e+18
# 2          0       False        True     1.179431e+18
# 3          0       False        True     1.189460e+18
# 4          0       False       False              NaN
# ...      ...         ...         ...              ...
# 1010       0       False        True     1.133401e+18
# 1011       0       False       False              NaN
# 1012       0       False       False              NaN
# 1013       0       False        True     1.136195e+18
# 1014       0       False        True     1.179391e+18
#
#                                          reply_to_users  classofspeech  month
# 0     [{'screen_name': 'JohnJCrace', 'user_id': '430...        neither      6
# 1     [{'screen_name': 'katcashmeade', 'user_id': '8...        neither      8
# 2     [{'screen_name': 'Jacob_Rees_Mogg', 'user_id':...        neither     10
# 3     [{'screen_name': 'johndante', 'user_id': '2751...        neither     10
# 4                                                    []        neither     10
# ...                                                 ...            ...    ...
# 1010  [{'screen_name': 'kennyzool', 'user_id': '2615...        neither      5
# 1011                                                 []        neither      7
# 1012                                                 []        neither      7
# 1013  [{'screen_name': 'Sillyshib', 'user_id': '8547...        neither      6
# 1014  [{'screen_name': 'allanholloway', 'user_id': '...        neither     10
#
# [1015 rows x 26 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 5     185
# 6     139
# 7     191
# 8     155
# 9     137
# 10    208
# Name: classofspeech, dtype: int64

# %%
d1['classofspeech'].unique()
# Out:
# array(['neither', 'offensive_language', 'hate_speech'], dtype=object)

# %%
o1=d1[d1['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, screen_name, username, user_id, tweet_id, tweet_url, timestamp, timestamp_epochs, text, text_html, links, hashtags, has_media, img_urls, video_url, likes, retweets, replies, is_replied, is_reply_to, parent_tweet_id, reply_to_users, classofspeech]
# Index: []
#
# [0 rows x 25 columns]

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 5               7             7               7            7         7
# 6               4             4               4            4         4
# 7               5             5               5            5         5
# 8               5             5               5            5         5
# 9               9             9               9            9         9
# 10              6             6               6            6         6
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 5            7         7          7          7                 7  ...
# 6            4         4          4          4                 4  ...
# 7            5         5          5          5                 5  ...
# 8            5         5          5          5                 5  ...
# 9            9         9          9          9                 9  ...
# 10           6         6          6          6                 6  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 5             7          0      7         7        7           7            7
# 6             4          0      4         4        4           4            4
# 7             5          0      5         5        5           5            5
# 8             5          0      5         5        5           5            5
# 9             9          0      9         9        9           9            9
# 10            6          0      6         6        6           6            6
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 5                    4               7              7
# 6                    2               4              4
# 7                    3               5              5
# 8                    3               5              5
# 9                    3               9              9
# 10                   3               6              6
#
# [6 rows x 25 columns]

# %%
sum(o['classofspeech'])
# Out:
# 36

# %%
pero=[]
for i in o['classofspeech']:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero
# Out:
# [19.444444444444443,
#  11.11111111111111,
#  13.88888888888889,
#  13.88888888888889,
#  25.0,
#  16.666666666666668]

# %%
xi=['May','June',"July",'August','September','October']

#for i in pero.index:
   # xi.append(i)
yi=[]

for i in pero:
    yi.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yi, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of offensive speech',fontsize=20)
ax.set_title("Percentage of offensive speech in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
n=d1[d1['classofspeech']=='neither'].groupby('month',sort=True).count()
n
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 5             178           178             178          178       178
# 6             134           134             134          134       134
# 7             186           186             186          186       186
# 8             150           150             150          150       150
# 9             128           128             128          128       128
# 10            202           202             202          202       202
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 5          178       178        178        178               178  ...
# 6          134       134        134        134               134  ...
# 7          186       186        186        186               186  ...
# 8          150       150        150        150               150  ...
# 9          128       128        128        128               128  ...
# 10         202       202        202        202               202  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 5           178          0    178       178      178         178          178
# 6           134          0    134       134      134         134          134
# 7           186          0    186       186      186         186          186
# 8           150          0    150       150      150         150          150
# 9           128          0    128       128      128         128          128
# 10          202          0    202       202      202         202          202
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 5                   84             178            178
# 6                   91             134            134
# 7                   95             186            186
# 8                   70             150            150
# 9                   59             128            128
# 10                  97             202            202
#
# [6 rows x 25 columns]

# %%
pern=[]
for i in n['classofspeech']:
    ans=i*100/sum(n['classofspeech'])
    #print (ans)
    pern.append(ans)
pern
# Out:
# [18.20040899795501,
#  13.701431492842536,
#  19.01840490797546,
#  15.337423312883436,
#  13.087934560327199,
#  20.65439672801636]

# %%
xi=['May','June',"July",'August','September','October']

#for i in pero.index:
   # xi.append(i)
yn=[]

for i in pern:
    yn.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yn, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of tweets neither offensive nor hate',fontsize=20)
ax.set_title("Percentage of tweets neither offensive nor hate in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
x=[]

for i in o['classofspeech'].index:
    x.append(i)
y=[]

for i in o['classofspeech']:
    y.append(i)
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number of offensive words',fontsize=20)
ax.set_title("Number of offensive words in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
from textblob import TextBlob
x=d1['text']
senti=[]
for i in x:
    senti.append(TextBlob(i).sentiment[0])
    #print (TextBlob(i).sentiment[0])
d1['senscores']=senti    
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0           621             621   CluelessTories
# 1              1          4385            4385      goodnitebob
# 2              2          8201            8201     Mr_P_Panther
# 3              3          4562            4562    JeanneBartram
# 4              4          8161            8161    DeannaNolan17
# ...          ...           ...             ...              ...
# 1010        1010          2874            2874      FrankieMac9
# 1011        1011          5500            5500  RhubarbVaselino
# 1012        1012          7399            7399  myerschrismyer1
# 1013        1013          2542            2542  GeordieJoeHardy
# 1014        1014          8235            8235    allanholloway
#
#                                                username              user_id  \
# 0             Citizen Smith - #FBPE5000#RevokeArticle50             44657626
# 1                                           goodnitebob  1064586673722454017
# 2                                      The Pink Panther   944224944170430464
# 3     Spider woman ÃÂ°ÃÂÃÂÃÂ·ÃÂ¯ÃÂ¸ÃÂ #Rev...            555337622
# 4                                          Deanna Nolan  1145426486905712650
# ...                                                 ...                  ...
# 1010                                       Frankie Mac9           4824152675
# 1011                                   Rhubarb Vaselino   849759279271866368
# 1012                                        Chris Myers   865262041103302656
# 1013                 Joe Hardy ÃÂ¢ÃÂÃÂ«ÃÂ¯ÃÂ¸ÃÂ   806113446546853888
# 1014                                           Arthur_S            129594482
#
#                  tweet_id                                    tweet_url  \
# 0     1142693298274017281   /CluelessTories/status/1142693298274017281
# 1     1162654770617868288      /goodnitebob/status/1162654770617868288
# 2     1179437737029574656     /Mr_P_Panther/status/1179437737029574656
# 3     1189669117797777410    /JeanneBartram/status/1189669117797777410
# 4     1179471663311798273    /DeannaNolan17/status/1179471663311798273
# ...                   ...                                          ...
# 1010  1133830545048264704      /FrankieMac9/status/1133830545048264704
# 1011  1148665305150963712  /RhubarbVaselino/status/1148665305150963712
# 1012  1152181227144785920  /myerschrismyer1/status/1152181227144785920
# 1013  1136197416116543488  /GeordieJoeHardy/status/1136197416116543488
# 1014  1179395666717609986    /allanholloway/status/1179395666717609986
#
#                 timestamp  timestamp_epochs  ... likes retweets replies  \
# 0     2019-06-23 07:18:07        1561274287  ...    11        0       0
# 1     2019-08-17 09:17:53        1566033473  ...     1        0       0
# 2     2019-10-02 16:47:24        1570034844  ...     0        0       0
# 3     2019-10-30 22:23:15        1572474195  ...     0        0       0
# 4     2019-10-02 19:02:12        1570042932  ...     2        3       0
# ...                   ...               ...  ...   ...      ...     ...
# 1010  2019-05-29 20:20:42        1559161242  ...     0        0       0
# 1011  2019-07-09 18:48:44        1562698124  ...     1        0       0
# 1012  2019-07-19 11:39:45        1563536385  ...     0        0       0
# 1013  2019-06-05 09:05:48        1559725548  ...     0        0       0
# 1014  2019-10-02 14:00:13        1570024813  ...     0        0       0
#
#      is_replied  is_reply_to parent_tweet_id  \
# 0         False         True    1.142680e+18
# 1         False         True    1.162394e+18
# 2         False         True    1.179431e+18
# 3         False         True    1.189460e+18
# 4         False        False             NaN
# ...         ...          ...             ...
# 1010      False         True    1.133401e+18
# 1011      False        False             NaN
# 1012      False        False             NaN
# 1013      False         True    1.136195e+18
# 1014      False         True    1.179391e+18
#
#                                          reply_to_users  classofspeech  month  \
# 0     [{'screen_name': 'JohnJCrace', 'user_id': '430...        neither      6
# 1     [{'screen_name': 'katcashmeade', 'user_id': '8...        neither      8
# 2     [{'screen_name': 'Jacob_Rees_Mogg', 'user_id':...        neither     10
# 3     [{'screen_name': 'johndante', 'user_id': '2751...        neither     10
# 4                                                    []        neither     10
# ...                                                 ...            ...    ...
# 1010  [{'screen_name': 'kennyzool', 'user_id': '2615...        neither      5
# 1011                                                 []        neither      7
# 1012                                                 []        neither      7
# 1013  [{'screen_name': 'Sillyshib', 'user_id': '8547...        neither      6
# 1014  [{'screen_name': 'allanholloway', 'user_id': '...        neither     10
#
#       senscores
# 0      0.037500
# 1      0.306926
# 2     -0.166667
# 3      0.000000
# 4      0.100000
# ...         ...
# 1010   0.000000
# 1011   0.068182
# 1012   0.250000
# 1013   0.000000
# 1014   0.000000
#
# [1015 rows x 27 columns]

# %%
len(d1)
# Out:
# 1015

# %%
b=d1.groupby('month',sort=True)['senscores'].mean()
b
# Out:
# month
# 5     0.060964
# 6     0.045451
# 7     0.065116
# 8     0.037535
# 9     0.090762
# 10    0.108617
# Name: senscores, dtype: float64

# %%
ys=[]

for i in b:
    ys.append(i)
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, ys,color='purple', marker='o', linestyle='dashed',linewidth=2, markersize=12)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores of six months',fontsize=20)
ax.set_title("Variation of sentimental scores",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
s = pd.Series(ys)
s=s*100
s
# Out:
# 0     6.096423
# 1     4.545092
# 2     6.511587
# 3     3.753536
# 4     9.076206
# 5    10.861666
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of offensive words in hundreds")

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores & number of offensive words',fontsize=17)
ax.set_title("Variation of mean sentimental scores of each month with offensive words",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
ax.plot(xi, perh1,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Percentage of hate speech")

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores and % of hate speeches',fontsize=17)
ax.set_title("Variation of mean sentimental scores with % of hate speech for each month",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-333abb4f99be> in <module>
#       1 fig, ax = plt.subplots(figsize=(15,7))
#       2 ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
# ----> 3 ax.plot(xi, perh1,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Percentage of hate speech")
#       4
#       5 ax.set_xlabel('Months',fontsize=20)
#
# NameError: name 'perh1' is not defined

# %%
d1=pd.read_csv("input2_threat_damecarolinespelman.csv",encoding="latin1")
d1
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0             0             0               0      john_carins
# 1             1             1               1      john_carins
# 2             2             2               2     deletedbyMPs
# 3             3             3               3     deletedbyMPs
# 4             4             4               4  IsabelleParasra
# ..          ...           ...             ...              ...
# 256         256           256             256       WalaaIdris
# 257         257           257             257       MonarchyUK
# 258         258           258             258  Conservative_JA
# 259         259           259             259      saramason18
# 260         260           260             260        a_adeyemo
#
#                                               username             user_id  \
# 0                                          John Carins  839507779438198785
# 1                                          John Carins  839507779438198785
# 2                                    Tweets MPs Delete          1066949670
# 3                                    Tweets MPs Delete          1066949670
# 4                   Isabelle Parasram ÃÂ°ÃÂÃÂÃÂ¶  742671341166465025
# ..                                                 ...                 ...
# 256                                  WalaaÃÂ¢ÃÂÃÂ¢            15861230
# 257                                    Charlie Proctor          1454119177
# 258  Jack ÃÂ°ÃÂÃÂÃÂ¬ÃÂ°ÃÂÃÂÃÂ§ÃÂ¢ÃÂÃ...  916394087908913153
# 259                                         sara mason           929380993
# 260                                        Ade Adeyemo           461451393
#
#                 tweet_id                                    tweet_url  \
# 0    1121419741791444992      /john_carins/status/1121419741791444992
# 1    1121419741791444992      /john_carins/status/1121419741791444992
# 2    1151762634099875840     /deletedbyMPs/status/1151762634099875840
# 3    1151762634099875840     /deletedbyMPs/status/1151762634099875840
# 4    1143844082969710593  /IsabelleParasra/status/1143844082969710593
# ..                   ...                                          ...
# 256  1169284940669837313       /WalaaIdris/status/1169284940669837313
# 257  1169284695823179777       /MonarchyUK/status/1169284695823179777
# 258  1169284430424367104  /Conservative_JA/status/1169284430424367104
# 259  1169153492084240385      /saramason18/status/1169153492084240385
# 260  1168801233303416833        /a_adeyemo/status/1168801233303416833
#
#                timestamp  timestamp_epochs  ... video_url likes retweets  \
# 0    2019-04-25 14:24:36        1556202276  ...       NaN     3        1
# 1    2019-04-25 14:24:36        1556202276  ...       NaN     3        1
# 2    2019-07-18 07:56:25        1563436585  ...       NaN     0        0
# 3    2019-07-18 07:56:25        1563436585  ...       NaN     0        0
# 4    2019-06-26 11:30:55        1561548655  ...       NaN    14        3
# ..                   ...               ...  ...       ...   ...      ...
# 256  2019-09-04 16:23:48        1567614228  ...       NaN     0        0
# 257  2019-09-04 16:22:50        1567614170  ...       NaN    87       43
# 258  2019-09-04 16:21:47        1567614107  ...       NaN    41        7
# 259  2019-09-04 07:41:28        1567582888  ...       NaN     0        0
# 260  2019-09-03 08:21:43        1567498903  ...       NaN     2        0
#
#     replies  is_replied is_reply_to  parent_tweet_id  \
# 0         0       False        True     1.121414e+18
# 1         0       False        True     1.121414e+18
# 2         0       False       False              NaN
# 3         0       False       False              NaN
# 4         0       False       False              NaN
# ..      ...         ...         ...              ...
# 256       0       False       False              NaN
# 257      12        True       False              NaN
# 258       6        True       False              NaN
# 259       0       False        True     1.168999e+18
# 260       2        True       False              NaN
#
#                                         reply_to_users  classofspeech  month
# 0    [{'screen_name': 'Lordbrexit', 'user_id': '277...        neither      4
# 1    [{'screen_name': 'Lordbrexit', 'user_id': '277...        neither      4
# 2                                                   []        neither      7
# 3                                                   []        neither      7
# 4                                                   []        neither      6
# ..                                                 ...            ...    ...
# 256                                                 []        neither      9
# 257                                                 []        neither      9
# 258                                                 []        neither      9
# 259  [{'screen_name': 'benjaminbutter', 'user_id': ...        neither      9
# 260                                                 []        neither      9
#
# [261 rows x 26 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 4     32
# 5     10
# 6     48
# 7      6
# 8     56
# 9    109
# Name: classofspeech, dtype: int64

# %%
d1['classofspeech'].unique()
# Out:
# array(['neither', 'offensive_language'], dtype=object)

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 9               1             1               1            1         1
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 9            1         1          1          1                 1  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 9             1          0      1         1        1           1            1
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 9                    0               1              1
#
# [1 rows x 25 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".7"})

d1=pd.read_csv("Carof1.csv",encoding="latin1")
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0             0               0     AJ_Thompson_
# 1              1             1               1  am1874northwich
# 2              2             2               2     SarahLudford
# 3              3             3               3     AJ_Thompson_
# 4              4             4               4  am1874northwich
# ...          ...           ...             ...              ...
# 1145        1145          1145            1145      Shoutout_UK
# 1146        1146          1146            1146           jen725
# 1147        1147          1147            1147         ollieD68
# 1148        1148          1148            1148      RandomThawt
# 1149        1149          1149            1149        GarethITV
#
#                                                username    user_id  \
# 0                                       Andrew Thompson  975164160
# 1     alan marshall Esq. ÃÂ°ÃÂÃÂÃÂªÃÂ°ÃÂÃÂ...   86504013
# 2     Sarah Ludford ÃÂ°ÃÂÃÂÃÂ¶ÃÂ°ÃÂÃÂÃÂ¶...  386630251
# 3                                       Andrew Thompson  975164160
# 4     alan marshall Esq. ÃÂ°ÃÂÃÂÃÂªÃÂ°ÃÂÃÂ...   86504013
# ...                                                 ...        ...
# 1145                                       Shout Out UK  348519505
# 1146                                             jen725   14494377
# 1147  Ollie4Revocation ÃÂ°ÃÂÃÂÃÂ¶ #RevokeA50 #...   56099359
# 1148                                     Crispin Driver  176914679
# 1149                                        Gareth Owen   18976529
#
#                  tweet_id                                    tweet_url  \
# 0     1128363927270825984     /AJ_Thompson_/status/1128363927270825984
# 1     1128274868833857536  /am1874northwich/status/1128274868833857536
# 2     1127549608836640768     /SarahLudford/status/1127549608836640768
# 3     1128363927270825984     /AJ_Thompson_/status/1128363927270825984
# 4     1128274868833857536  /am1874northwich/status/1128274868833857536
# ...                   ...                                          ...
# 1145  1169285105958957056      /Shoutout_UK/status/1169285105958957056
# 1146  1169285098916761600           /jen725/status/1169285098916761600
# 1147  1169285094936391680         /ollieD68/status/1169285094936391680
# 1148  1169285071083360256      /RandomThawt/status/1169285071083360256
# 1149  1169285063084847104        /GarethITV/status/1169285063084847104
#
#                 timestamp  timestamp_epochs  ... video_url likes retweets  \
# 0     2019-05-14 18:18:18        1557857898  ...       NaN     2        1
# 1     2019-05-14 12:24:25        1557836665  ...       NaN     1        1
# 2     2019-05-12 12:22:30        1557663750  ...       NaN    43       23
# 3     2019-05-14 18:18:18        1557857898  ...       NaN     2        1
# 4     2019-05-14 12:24:25        1557836665  ...       NaN     1        1
# ...                   ...               ...  ...       ...   ...      ...
# 1145  2019-09-04 16:24:28        1567614268  ...       NaN     0        1
# 1146  2019-09-04 16:24:26        1567614266  ...       NaN     1        0
# 1147  2019-09-04 16:24:25        1567614265  ...       NaN     0        0
# 1148  2019-09-04 16:24:19        1567614259  ...       NaN    10        0
# 1149  2019-09-04 16:24:17        1567614257  ...       NaN     5        4
#
#      replies  is_replied is_reply_to  parent_tweet_id  \
# 0          0       False       False              NaN
# 1          0       False       False              NaN
# 2          1        True       False              NaN
# 3          0       False       False              NaN
# 4          0       False       False              NaN
# ...      ...         ...         ...              ...
# 1145       0       False       False              NaN
# 1146       0       False        True     1.169284e+18
# 1147       0       False        True     1.169273e+18
# 1148       0       False        True     1.169284e+18
# 1149       2        True       False              NaN
#
#                                          reply_to_users  classofspeech  month
# 0                                                    []        neither      5
# 1                                                    []        neither      5
# 2                                                    []        neither      5
# 3                                                    []        neither      5
# 4                                                    []        neither      5
# ...                                                 ...            ...    ...
# 1145                                                 []        neither      9
# 1146  [{'screen_name': 'pashazaded', 'user_id': '887...        neither      9
# 1147  [{'screen_name': 'IanDunt', 'user_id': '212028...        neither      9
# 1148  [{'screen_name': 'disinformedia', 'user_id': '...        neither      9
# 1149                                                 []        neither      9
#
# [1150 rows x 26 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 4    113
# 5     42
# 6    194
# 7     44
# 8    205
# 9    552
# Name: classofspeech, dtype: int64

# %%
o2=d1[d1['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, screen_name, username, user_id, tweet_id, tweet_url, timestamp, timestamp_epochs, text, text_html, links, hashtags, has_media, img_urls, video_url, likes, retweets, replies, is_replied, is_reply_to, parent_tweet_id, reply_to_users, classofspeech]
# Index: []
#
# [0 rows x 25 columns]

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 4               7             7               7            7         7
# 5               2             2               2            2         2
# 6               8             8               8            8         8
# 7               6             6               6            6         6
# 8               7             7               7            7         7
# 9              17            17              17           17        17
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 4            7         7          7          7                 7  ...
# 5            2         2          2          2                 2  ...
# 6            8         8          8          8                 8  ...
# 7            6         6          6          6                 6  ...
# 8            7         7          7          7                 7  ...
# 9           17        17         17         17                17  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 4             7          0      7         7        7           7            7
# 5             2          0      2         2        2           2            2
# 6             8          0      8         8        8           8            8
# 7             6          0      6         6        6           6            6
# 8             7          0      7         7        7           7            7
# 9            17          0     17        17       17          17           17
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 4                    5               7              7
# 5                    0               2              2
# 6                    6               8              8
# 7                    2               6              6
# 8                    3               7              7
# 9                    6              17             17
#
# [6 rows x 25 columns]

# %%
sum(o['classofspeech'])
# Out:
# 47

# %%
pero=[]
for i in o['classofspeech']:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero
# Out:
# [14.893617021276595,
#  4.25531914893617,
#  17.02127659574468,
#  12.76595744680851,
#  14.893617021276595,
#  36.170212765957444]

# %%
xi=['April','May','June',"July",'August','September']

#for i in pero.index:
   # xi.append(i)
yi=[]

for i in pero:
    yi.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yi, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of offensive speech',fontsize=20)
ax.set_title("Percentage of offensive speech in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".7"})

d=pd.read_csv("Mark1f1.csv",encoding="latin1")
len(d)
# Out:
# 1150

# %%
o=d[d['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 4               7             7               7            7         7
# 5               2             2               2            2         2
# 6               8             8               8            8         8
# 7               6             6               6            6         6
# 8               7             7               7            7         7
# 9              17            17              17           17        17
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 4            7         7          7          7                 7  ...
# 5            2         2          2          2                 2  ...
# 6            8         8          8          8                 8  ...
# 7            6         6          6          6                 6  ...
# 8            7         7          7          7                 7  ...
# 9           17        17         17         17                17  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 4             7          0      7         7        7           7            7
# 5             2          0      2         2        2           2            2
# 6             8          0      8         8        8           8            8
# 7             6          0      6         6        6           6            6
# 8             7          0      7         7        7           7            7
# 9            17          0     17        17       17          17           17
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 4                    5               7              7
# 5                    0               2              2
# 6                    6               8              8
# 7                    2               6              6
# 8                    3               7              7
# 9                    6              17             17
#
# [6 rows x 25 columns]

# %%
sum(o['classofspeech'])
# Out:
# 47

# %%
x1=['June','July','August','September','October','November']
y1=[0,0,0,0,40,60]

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")

ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#

ax.set_xlabel('Months',fontsize=20)
plt.plot('September',36.170212765957444, markersize=24,marker='X')
plt.plot('November',60, markersize=24,marker='X')

ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive words where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
pero
# Out:
# [14.893617021276595,
#  4.25531914893617,
#  17.02127659574468,
#  12.76595744680851,
#  14.893617021276595,
#  36.170212765957444]
