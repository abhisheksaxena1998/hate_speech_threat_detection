# %%
pip install twitterscraper
# Out:
# Collecting twitterscraper
#   Downloading https://files.pythonhosted.org/packages/7f/0f/7cf31233d4f5616c971f6b1ae22dd73fe9a69430877f5c37a0e7b508a311/twitterscraper-1.4.0.tar.gz
# Collecting coala-utils~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/54/00/74ec750cfc4e830f9d1cfdd4d559f3d2d4ba1b834b78d5266446db3fd1d6/coala_utils-0.5.1-py3-none-any.whl
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/bc/87/c3cecadcb5d7924cd71724b177343149cfc3609a89b197a991ac8593ed8c/lxml-4.4.1-cp37-cp37m-win_amd64.whl (3.7MB)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from twitterscraper) (2.22.0)
# Collecting billiard
#   Downloading https://files.pythonhosted.org/packages/9a/bb/2a016ac912fca48e06ff5a662407f3d1681aa47df97fb19feba7cc931ee1/billiard-3.6.1.0-py3-none-any.whl (89kB)
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/3b/c8/a55eb6ea11cd7e5ac4bacdf92bac4693b90d3ba79268be16527555e186f0/beautifulsoup4-4.8.1-py3-none-any.whl (101kB)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (1.25.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (2019.9.11)
# Collecting soupsieve>=1.2
#   Downloading https://files.pythonhosted.org/packages/81/94/03c0f04471fc245d08d0a99f7946ac228ca98da4fa75796c507f61e688c2/soupsieve-1.9.5-py2.py3-none-any.whl
# Building wheels for collected packages: twitterscraper, bs4
#   Building wheel for twitterscraper (setup.py): started
#   Building wheel for twitterscraper (setup.py): finished with status 'done'
#   Created wheel for twitterscraper: filename=twitterscraper-1.4.0-cp37-none-any.whl size=11351 sha256=4c25419cf9fa3b0c12f546743da344d61e861577d713e2ae5df37a11d03b655f
#   Stored in directory: C:\Users\DELL\AppData\Local\pip\Cache\wheels\c2\9c\8b\7393e7bdc8abe6ce0d46c2ffae2035a1a2080a97ff0ddbdde6
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-cp37-none-any.whl size=1278 sha256=b2d4bd883091aca2156e7b221fd2193e85c01dceee5686ce95054fb16f7b8533
#   Stored in directory: C:\Users\DELL\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built twitterscraper bs4
# Installing collected packages: coala-utils, soupsieve, beautifulsoup4, bs4, lxml, billiard, twitterscraper
# Successfully installed beautifulsoup4-4.8.1 billiard-3.6.1.0 bs4-0.0.1 coala-utils-0.5.1 lxml-4.4.1 soupsieve-1.9.5 twitterscraper-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/23/4e/1254d26ce5d36facdcbb5820e7e434328aed68e99938c75c9d4e2fee5efb/wordcloud-1.5.0-cp37-cp37m-win_amd64.whl (153kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from wordcloud) (1.17.4)
# Collecting pillow
#   Downloading https://files.pythonhosted.org/packages/70/f4/9dd0b7b0fea09cf4e7a2822031f2157f40d41f0252a89558bdb583e24ef1/Pillow-6.2.1-cp37-cp37m-win_amd64.whl (2.0MB)
# Installing collected packages: pillow, wordcloud
# Successfully installed pillow-6.2.1 wordcloud-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import datetime as dt 
from twitterscraper import query_tweets
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import re
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}

# %%
# taking necessary input like date range , topic string to search 
start_y=int(input())
start_m=int(input())
start_d=int(input())
end_y=int(input())
end_m=int(input())
end_d=int(input())
search_topic=input()
# default language is english
lang= 'english'

#assigning dates , querying the tweets using the imported packeges

begin_date=dt.date(start_y,start_m,start_d)
end_date=dt.date(end_y,end_m,end_d)
limit=10000
tweet_data=query_tweets(search_topic,begindate=begin_date , enddate=end_date, limit=limit ,lang=lang)

# creating a csv file of collected tweets data
df=pd.DataFrame(obj.__dict__ for obj in tweet_data)
#df.drop(['timestamp_epochs','html'],axis=1)
df.to_csv('Justine Greening.csv')

comment_words=' '
stopwords = set(STOPWORDS) 
for val in df['text']:
    t=set()
    val = re.sub('https?://[A-Za-z0-9./]+','',val) 
    tokens = val.split()  
    for word in tokens:
      t.add(word.lower())
    t=list(t)  
    for words in t: 
        comment_words = comment_words + words + ' '
   
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
                          
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# 2019
# 04
# 1
# 2019
# 9
# 30
# Justine Greening
# INFO: queries: ['Justine Greening since:2019-04-01 until:2019-04-10', 'Justine Greening since:2019-04-10 until:2019-04-19', 'Justine Greening since:2019-04-19 until:2019-04-28', 'Justine Greening since:2019-04-28 until:2019-05-07', 'Justine Greening since:2019-05-07 until:2019-05-16', 'Justine Greening since:2019-05-16 until:2019-05-25', 'Justine Greening since:2019-05-25 until:2019-06-03', 'Justine Greening since:2019-06-03 until:2019-06-12', 'Justine Greening since:2019-06-12 until:2019-06-21', 'Justine Greening since:2019-06-21 until:2019-07-01', 'Justine Greening since:2019-07-01 until:2019-07-10', 'Justine Greening since:2019-07-10 until:2019-07-19', 'Justine Greening since:2019-07-19 until:2019-07-28', 'Justine Greening since:2019-07-28 until:2019-08-06', 'Justine Greening since:2019-08-06 until:2019-08-15', 'Justine Greening since:2019-08-15 until:2019-08-24', 'Justine Greening since:2019-08-24 until:2019-09-02', 'Justine Greening since:2019-09-02 until:2019-09-11', 'Justine Greening since:2019-09-11 until:2019-09-20', 'Justine Greening since:2019-09-20 until:2019-09-30']
# INFO: Got 210 tweets (210 new).
# INFO: Got 492 tweets (282 new).
# INFO: Got 838 tweets (346 new).
# INFO: Got 1247 tweets (409 new).
# INFO: Got 1691 tweets (444 new).
# INFO: Got 2195 tweets (504 new).
# INFO: Got 2700 tweets (505 new).
# INFO: Got 3213 tweets (513 new).
# INFO: Got 3720 tweets (507 new).
# INFO: Got 4222 tweets (502 new).
# INFO: Got 4731 tweets (509 new).
# INFO: Got 5242 tweets (511 new).
# INFO: Got 5754 tweets (512 new).
# INFO: Got 6260 tweets (506 new).
# INFO: Got 6771 tweets (511 new).
# INFO: Got 7291 tweets (520 new).
# INFO: Got 7805 tweets (514 new).
# INFO: Got 8309 tweets (504 new).
# INFO: Got 8827 tweets (518 new).
# INFO: Got 9338 tweets (511 new).

# %%
# taking necessary input like date range , topic string to search 
start_y=int(input())
start_m=int(input())
start_d=int(input())
end_y=int(input())
end_m=int(input())
end_d=int(input())
search_topic=input()
# default language is english
lang= 'english'

#assigning dates , querying the tweets using the imported packeges

begin_date=dt.date(start_y,start_m,start_d)
end_date=dt.date(end_y,end_m,end_d)
limit=10000
tweet_data=query_tweets(search_topic,begindate=begin_date , enddate=end_date, limit=limit ,lang=lang)

# creating a csv file of collected tweets data
df=pd.DataFrame(obj.__dict__ for obj in tweet_data)
#df.drop(['timestamp_epochs','html'],axis=1)
df.to_csv('Nicky Morgan.csv')

comment_words=' '
stopwords = set(STOPWORDS) 
for val in df['text']:
    t=set()
    val = re.sub('https?://[A-Za-z0-9./]+','',val) 
    tokens = val.split()  
    for word in tokens:
      t.add(word.lower())
    t=list(t)  
    for words in t: 
        comment_words = comment_words + words + ' '
   
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
                          
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# 2019
# 5
# 1
# 2019
# 10
# 31
# Nicky Morgan
# INFO: queries: ['Nicky Morgan since:2019-05-01 until:2019-05-10', 'Nicky Morgan since:2019-05-10 until:2019-05-19', 'Nicky Morgan since:2019-05-19 until:2019-05-28', 'Nicky Morgan since:2019-05-28 until:2019-06-06', 'Nicky Morgan since:2019-06-06 until:2019-06-15', 'Nicky Morgan since:2019-06-15 until:2019-06-24', 'Nicky Morgan since:2019-06-24 until:2019-07-04', 'Nicky Morgan since:2019-07-04 until:2019-07-13', 'Nicky Morgan since:2019-07-13 until:2019-07-22', 'Nicky Morgan since:2019-07-22 until:2019-07-31', 'Nicky Morgan since:2019-07-31 until:2019-08-09', 'Nicky Morgan since:2019-08-09 until:2019-08-18', 'Nicky Morgan since:2019-08-18 until:2019-08-27', 'Nicky Morgan since:2019-08-27 until:2019-09-06', 'Nicky Morgan since:2019-09-06 until:2019-09-15', 'Nicky Morgan since:2019-09-15 until:2019-09-24', 'Nicky Morgan since:2019-09-24 until:2019-10-03', 'Nicky Morgan since:2019-10-03 until:2019-10-12', 'Nicky Morgan since:2019-10-12 until:2019-10-21', 'Nicky Morgan since:2019-10-21 until:2019-10-31']
# INFO: Got 99 tweets (99 new).
# INFO: Got 214 tweets (115 new).
# INFO: Got 324 tweets (110 new).
# INFO: Got 455 tweets (131 new).
# INFO: Got 586 tweets (131 new).
# INFO: Got 723 tweets (137 new).
# INFO: Got 858 tweets (135 new).
# INFO: Got 1006 tweets (148 new).
# INFO: Got 1185 tweets (179 new).
# INFO: Got 1393 tweets (208 new).
# INFO: Got 1677 tweets (284 new).
# INFO: Got 2147 tweets (470 new).
# INFO: Got 2650 tweets (503 new).
# INFO: Got 3164 tweets (514 new).
# INFO: Got 3666 tweets (502 new).
# INFO: Got 4186 tweets (520 new).
# INFO: Got 4705 tweets (519 new).
# INFO: Got 5221 tweets (516 new).
# INFO: Got 5737 tweets (516 new).
# INFO: Got 6255 tweets (518 new).

# %% [markdown]
# # Stephen Twigg

# %%
# taking necessary input like date range , topic string to search 
start_y=int(input())
start_m=int(input())
start_d=int(input())
end_y=int(input())
end_m=int(input())
end_d=int(input())
search_topic=input()
# default language is english
lang= 'english'

#assigning dates , querying the tweets using the imported packeges

begin_date=dt.date(start_y,start_m,start_d)
end_date=dt.date(end_y,end_m,end_d)
limit=10000
tweet_data=query_tweets(search_topic,begindate=begin_date , enddate=end_date, limit=limit ,lang=lang)

# creating a csv file of collected tweets data
df=pd.DataFrame(obj.__dict__ for obj in tweet_data)
#df.drop(['timestamp_epochs','html'],axis=1)
df.to_csv('Stephen Twigg.csv')

comment_words=' '
stopwords = set(STOPWORDS) 
for val in df['text']:
    t=set()
    val = re.sub('https?://[A-Za-z0-9./]+','',val) 
    tokens = val.split()  
    for word in tokens:
      t.add(word.lower())
    t=list(t)  
    for words in t: 
        comment_words = comment_words + words + ' '
   
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
                          
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
