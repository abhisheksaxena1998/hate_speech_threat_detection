# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".6"})

d1=pd.read_csv("final Alan Duncan.csv",encoding="latin1")
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1      screen_name  \
# 0           1593          1593     JimPickworth
# 1            465           465      PixieSteven
# 2           1615          1615            G3JKL
# 3            490           490      Dr_Theodora
# 4           1926          1926    Johnallsopp12
# ...          ...           ...              ...
# 1176        3173          3173        JRLHarris
# 1177        3717          3717  Michael71116154
# 1178         111           111     MattGunner32
# 1179        2310          2310     BrexitLondon
# 1180        1089          1089   Life_Disrupted
#
#                                                username              user_id  \
# 0                                           jimbobags67            946852621
# 1     #CatsofDurham PRINCESS AND THOMAS #FindMissing...   810773762362707968
# 2                                           John Lovell             20597212
# 3                                     Theodora Christou           1324666688
# 4               THE NORTHERNER Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂ¤Âª  1096481855111655424
# ...                                                 ...                  ...
# 1176                     Joseph Harris Ã°ÂÂÂªÃ°ÂÂÂº           4203800363
# 1177                                      Michael Watts   914534354948444165
# 1178                                       MattGunner32            334869752
# 1179                                PeterThompsonLondon   836721050008313857
# 1180                                        Sarah Hurst   889039269637091330
#
#                  tweet_id                                    tweet_url  \
# 0     1138545291156697088     /JimPickworth/status/1138545291156697088
# 1     1142415909996441600      /PixieSteven/status/1142415909996441600
# 2     1138415257381212160            /G3JKL/status/1138415257381212160
# 3     1141100396913598474      /Dr_Theodora/status/1141100396913598474
# 4     1149961723862011904    /Johnallsopp12/status/1149961723862011904
# ...                   ...                                          ...
# 1176  1149245960415064066        /JRLHarris/status/1149245960415064066
# 1177  1153634076143816709  /Michael71116154/status/1153634076143816709
# 1178  1156937695362465793     /MattGunner32/status/1156937695362465793
# 1179  1128031636103335936     /BrexitLondon/status/1128031636103335936
# 1180  1176079783664529408   /Life_Disrupted/status/1176079783664529408
#
#                 timestamp  timestamp_epochs  \
# 0     2019-06-11 20:35:25        1560285325
# 1     2019-06-22 12:55:52        1561208152
# 2     2019-06-11 11:58:42        1560254322
# 3     2019-06-18 21:48:29        1560894509
# 4     2019-07-13 08:40:14        1563007214
# ...                   ...               ...
# 1176  2019-07-11 09:16:03        1562836563
# 1177  2019-07-23 11:52:51        1563882771
# 1178  2019-08-01 14:40:16        1564670416
# 1179  2019-05-13 20:17:54        1557778674
# 1180  2019-09-23 10:24:05        1569234245
#
#                                                    text  ... video_url likes  \
# 0     Alan Duncan: everyone who has ever worked with...  ...       NaN     0
# 1     Alan Duncan says Conservative Home is Ã¢ÂÂir...  ...       NaN     3
# 2                      Alan Duncan squirming around....  ...       NaN     7
# 3     Helena Smith joins Alan Duncan Smith to say th...  ...       NaN    10
# 4     Let's have a quick look at part of the WA, and...  ...       NaN     0
# ...                                                 ...  ...       ...   ...
# 1176  Jeremy Thorpe was gay.\nAlan Duncan is gay.\nW...  ...       NaN     3
# 1177  ROBERT what you have missed is that Alan Dunca...  ...       NaN     0
# 1178  Any chance you can squeeze in Alan Duncan Esq,...  ...       NaN     0
# 1179  EU remainer #AlanDuncan MP - the one who said ...  ...       NaN     1
# 1180  Alan Duncan earlier this year: "It's another d...  ...       NaN    12
#
#      retweets  replies is_replied  is_reply_to  parent_tweet_id  \
# 0           0        0      False         True     1.138359e+18
# 1           2        0      False        False              NaN
# 2           1        0      False         True     1.138413e+18
# 3           3        3       True        False              NaN
# 4           0        0      False         True     1.149308e+18
# ...       ...      ...        ...          ...              ...
# 1176        0        2       True        False              NaN
# 1177        0        0      False         True     1.153319e+18
# 1178        0        0      False         True     1.156933e+18
# 1179        0        0      False        False              NaN
# 1180        6        0      False        False              NaN
#
#                                          reply_to_users       classofspeech  \
# 0     [{'screen_name': 'tomcopley', 'user_id': '1347...             neither
# 1                                                    []             neither
# 2     [{'screen_name': 'LeaveEUOfficial', 'user_id':...             neither
# 3                                                    []             neither
# 4     [{'screen_name': 'TheFogeys', 'user_id': '7200...             neither
# ...                                                 ...                 ...
# 1176                                                 []             neither
# 1177  [{'screen_name': 'Peston', 'user_id': '1415713...             neither
# 1178  [{'screen_name': 'IainDale', 'user_id': '58380...             neither
# 1179                                                 []             neither
# 1180                                                 []  offensive_language
#
#       month
# 0         6
# 1         6
# 2         6
# 3         6
# 4         7
# ...     ...
# 1176      7
# 1177      7
# 1178      8
# 1179      5
# 1180      9
#
# [1181 rows x 25 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 5     172
# 6     184
# 7     381
# 8      80
# 9     240
# 10    124
# Name: classofspeech, dtype: int64

# %%
d1['classofspeech'].unique()
# Out:
# array(['neither', 'offensive_language'], dtype=object)

# %%
o1=d1[d1['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, screen_name, username, user_id, tweet_id, tweet_url, timestamp, timestamp_epochs, text, text_html, links, hashtags, has_media, img_urls, video_url, likes, retweets, replies, is_replied, is_reply_to, parent_tweet_id, reply_to_users, classofspeech]
# Index: []
#
# [0 rows x 24 columns]

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  screen_name  username  user_id  tweet_id  \
# month
# 5               7             7            7         7        7         7
# 6              10            10           10        10       10        10
# 7              13            13           13        13       13        13
# 8               3             3            3         3        3         3
# 9               7             7            7         7        7         7
# 10              8             8            8         8        8         8
#
#        tweet_url  timestamp  timestamp_epochs  text  ...  img_urls  video_url  \
# month                                                ...
# 5              7          7                 7     7  ...         7          0
# 6             10         10                10    10  ...        10          0
# 7             13         13                13    13  ...        13          0
# 8              3          3                 3     3  ...         3          0
# 9              7          7                 7     7  ...         7          0
# 10             8          8                 8     8  ...         8          0
#
#        likes  retweets  replies  is_replied  is_reply_to  parent_tweet_id  \
# month
# 5          7         7        7           7            7                3
# 6         10        10       10          10           10                5
# 7         13        13       13          13           13                8
# 8          3         3        3           3            3                3
# 9          7         7        7           7            7                1
# 10         8         8        8           8            8                4
#
#        reply_to_users  classofspeech
# month
# 5                   7              7
# 6                  10             10
# 7                  13             13
# 8                   3              3
# 9                   7              7
# 10                  8              8
#
# [6 rows x 24 columns]

# %%
sum(o['classofspeech'])
# Out:
# 48

# %%
oz=[3,7,8,7,10,13]

# %%
pero=[]
for i in oz:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero
# Out:
# [6.25,
#  14.583333333333334,
#  16.666666666666668,
#  14.583333333333334,
#  20.833333333333332,
#  27.083333333333332]

# %%
xi=['February','March','April','May','June',"July"]

#for i in pero.index:
   # xi.append(i)
yi=[]

for i in pero:
    yi.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yi, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of offensive speech',fontsize=20)
ax.set_title("Percentage of offensive speech in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
n=d1[d1['classofspeech']=='neither'].groupby('month',sort=True).count()
n
# Out:
#        Unnamed: 0  Unnamed: 0.1  screen_name  username  user_id  tweet_id  \
# month
# 5             165           165          165       165      165       165
# 6             174           174          174       174      174       174
# 7             368           368          368       368      368       368
# 8              77            77           77        77       77        77
# 9             233           233          233       233      233       233
# 10            116           116          116       116      116       116
#
#        tweet_url  timestamp  timestamp_epochs  text  ...  img_urls  video_url  \
# month                                                ...
# 5            165        165               165   165  ...       165          0
# 6            174        174               174   174  ...       174          0
# 7            368        368               368   368  ...       368          0
# 8             77         77                77    77  ...        77          0
# 9            233        233               233   233  ...       233          0
# 10           116        116               116   116  ...       116          0
#
#        likes  retweets  replies  is_replied  is_reply_to  parent_tweet_id  \
# month
# 5        165       165      165         165          165               94
# 6        174       174      174         174          174               92
# 7        368       368      368         368          368              187
# 8         77        77       77          77           77               55
# 9        233       233      233         233          233               94
# 10       116       116      116         116          116               66
#
#        reply_to_users  classofspeech
# month
# 5                 165            165
# 6                 174            174
# 7                 368            368
# 8                  77             77
# 9                 233            233
# 10                116            116
#
# [6 rows x 24 columns]

# %%
pern=[]
for i in n['classofspeech']:
    ans=i*100/sum(n['classofspeech'])
    #print (ans)
    pern.append(ans)
pern
# Out:
# [14.563106796116505,
#  15.357458075904677,
#  32.48014121800529,
#  6.796116504854369,
#  20.5648720211827,
#  10.238305383936451]

# %%
xi=['February','March','April','May','June',"July",'August']

#for i in pero.index:
   # xi.append(i)
yn=[]

for i in pern:
    yn.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yn, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of tweets neither offensive nor hate',fontsize=20)
ax.set_title("Percentage of tweets neither offensive nor hate in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a6d88aa8680e> in <module>
#       8     yn.append(i)
#       9 fig, ax = plt.subplots(figsize=(15,7))
# ---> 10 plt.bar(xi, yn, edgecolor = 'black', linewidth=2)
#      11
#      12 ax.set_xlabel('Months',fontsize=20)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
y=[]

for i in oz:
    y.append(i)
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number of offensive words',fontsize=20)
ax.set_title("Number of offensive words in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-e6c5a86621be> in <module>
#       4     y.append(i)
#       5 fig, ax = plt.subplots(figsize=(15,7))
# ----> 6 ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12)
#       7
#       8 ax.set_xlabel('Months',fontsize=20)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (7,) and (6,)

# %%
from textblob import TextBlob
x=d1['text']
senti=[]
for i in x:
    senti.append(TextBlob(i).sentiment[0])
    #print (TextBlob(i).sentiment[0])
d1['senscores']=senti    
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1      screen_name  \
# 0           1593          1593     JimPickworth
# 1            465           465      PixieSteven
# 2           1615          1615            G3JKL
# 3            490           490      Dr_Theodora
# 4           1926          1926    Johnallsopp12
# ...          ...           ...              ...
# 1176        3173          3173        JRLHarris
# 1177        3717          3717  Michael71116154
# 1178         111           111     MattGunner32
# 1179        2310          2310     BrexitLondon
# 1180        1089          1089   Life_Disrupted
#
#                                                username              user_id  \
# 0                                           jimbobags67            946852621
# 1     #CatsofDurham PRINCESS AND THOMAS #FindMissing...   810773762362707968
# 2                                           John Lovell             20597212
# 3                                     Theodora Christou           1324666688
# 4               THE NORTHERNER Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂ¤Âª  1096481855111655424
# ...                                                 ...                  ...
# 1176                     Joseph Harris Ã°ÂÂÂªÃ°ÂÂÂº           4203800363
# 1177                                      Michael Watts   914534354948444165
# 1178                                       MattGunner32            334869752
# 1179                                PeterThompsonLondon   836721050008313857
# 1180                                        Sarah Hurst   889039269637091330
#
#                  tweet_id                                    tweet_url  \
# 0     1138545291156697088     /JimPickworth/status/1138545291156697088
# 1     1142415909996441600      /PixieSteven/status/1142415909996441600
# 2     1138415257381212160            /G3JKL/status/1138415257381212160
# 3     1141100396913598474      /Dr_Theodora/status/1141100396913598474
# 4     1149961723862011904    /Johnallsopp12/status/1149961723862011904
# ...                   ...                                          ...
# 1176  1149245960415064066        /JRLHarris/status/1149245960415064066
# 1177  1153634076143816709  /Michael71116154/status/1153634076143816709
# 1178  1156937695362465793     /MattGunner32/status/1156937695362465793
# 1179  1128031636103335936     /BrexitLondon/status/1128031636103335936
# 1180  1176079783664529408   /Life_Disrupted/status/1176079783664529408
#
#                 timestamp  timestamp_epochs  \
# 0     2019-06-11 20:35:25        1560285325
# 1     2019-06-22 12:55:52        1561208152
# 2     2019-06-11 11:58:42        1560254322
# 3     2019-06-18 21:48:29        1560894509
# 4     2019-07-13 08:40:14        1563007214
# ...                   ...               ...
# 1176  2019-07-11 09:16:03        1562836563
# 1177  2019-07-23 11:52:51        1563882771
# 1178  2019-08-01 14:40:16        1564670416
# 1179  2019-05-13 20:17:54        1557778674
# 1180  2019-09-23 10:24:05        1569234245
#
#                                                    text  ... likes retweets  \
# 0     Alan Duncan: everyone who has ever worked with...  ...     0        0
# 1     Alan Duncan says Conservative Home is Ã¢ÂÂir...  ...     3        2
# 2                      Alan Duncan squirming around....  ...     7        1
# 3     Helena Smith joins Alan Duncan Smith to say th...  ...    10        3
# 4     Let's have a quick look at part of the WA, and...  ...     0        0
# ...                                                 ...  ...   ...      ...
# 1176  Jeremy Thorpe was gay.\nAlan Duncan is gay.\nW...  ...     3        0
# 1177  ROBERT what you have missed is that Alan Dunca...  ...     0        0
# 1178  Any chance you can squeeze in Alan Duncan Esq,...  ...     0        0
# 1179  EU remainer #AlanDuncan MP - the one who said ...  ...     1        0
# 1180  Alan Duncan earlier this year: "It's another d...  ...    12        6
#
#      replies  is_replied is_reply_to  parent_tweet_id  \
# 0          0       False        True     1.138359e+18
# 1          0       False       False              NaN
# 2          0       False        True     1.138413e+18
# 3          3        True       False              NaN
# 4          0       False        True     1.149308e+18
# ...      ...         ...         ...              ...
# 1176       2        True       False              NaN
# 1177       0       False        True     1.153319e+18
# 1178       0       False        True     1.156933e+18
# 1179       0       False       False              NaN
# 1180       0       False       False              NaN
#
#                                          reply_to_users       classofspeech  \
# 0     [{'screen_name': 'tomcopley', 'user_id': '1347...             neither
# 1                                                    []             neither
# 2     [{'screen_name': 'LeaveEUOfficial', 'user_id':...             neither
# 3                                                    []             neither
# 4     [{'screen_name': 'TheFogeys', 'user_id': '7200...             neither
# ...                                                 ...                 ...
# 1176                                                 []             neither
# 1177  [{'screen_name': 'Peston', 'user_id': '1415713...             neither
# 1178  [{'screen_name': 'IainDale', 'user_id': '58380...             neither
# 1179                                                 []             neither
# 1180                                                 []  offensive_language
#
#       month  senscores
# 0         6   0.000000
# 1         6   0.250000
# 2         6   0.000000
# 3         6   0.085268
# 4         7   0.333333
# ...     ...        ...
# 1176      7   0.411111
# 1177      7   0.000000
# 1178      8   0.000000
# 1179      5   0.000000
# 1180      9  -0.200000
#
# [1181 rows x 26 columns]

# %%
len(d1)
# Out:
# 1181

# %%
b=d1.groupby('month',sort=True)['senscores'].mean()
b
# Out:
# month
# 5     0.018993
# 6     0.021955
# 7     0.020995
# 8     0.085931
# 9     0.062143
# 10    0.075604
# Name: senscores, dtype: float64

# %%
ys=[]

for i in b:
    ys.append(i)
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, ys,color='purple', marker='o', linestyle='dashed',linewidth=2, markersize=12)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores of six months',fontsize=20)
ax.set_title("Variation of sentimental scores",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-711ade920bee> in <module>
#       4     ys.append(i)
#       5 fig, ax = plt.subplots(figsize=(15,7))
# ----> 6 ax.plot(xi, ys,color='purple', marker='o', linestyle='dashed',linewidth=2, markersize=12)
#       7
#       8 ax.set_xlabel('Months',fontsize=20)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (7,) and (6,)

# %%
s = pd.Series(ys)
s=s*100
s
# Out:
# 0    1.899296
# 1    2.195531
# 2    2.099519
# 3    8.593125
# 4    6.214289
# 5    7.560446
# dtype: float64

# %%
xi=['February', 'March', 'April', 'May', 'June', 'July']

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of offensive tweets")
plt.plot('July',13, markersize=24,marker='X')
plt.yticks([-10,0,10,20,30,40,50,60,70])
ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores*100 & number of offensive tweets',fontsize=17)
ax.set_title("Variation of mean sentiment scores of each month with offensive tweets for Alan Duncan",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
ax.plot(xi, perh1,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Percentage of hate speech")

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores and % of hate speeches',fontsize=17)
ax.set_title("Variation of mean sentimental scores with % of hate speech for each month",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-333abb4f99be> in <module>
#       1 fig, ax = plt.subplots(figsize=(15,7))
#       2 ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
# ----> 3 ax.plot(xi, perh1,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Percentage of hate speech")
#       4
#       5 ax.set_xlabel('Months',fontsize=20)
#
# NameError: name 'perh1' is not defined

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 5     172
# 6     184
# 7     381
# 8      80
# 9     240
# 10    124
# Name: classofspeech, dtype: int64

# %%
d1['classofspeech'].unique()
# Out:
# array(['neither', 'offensive_language'], dtype=object)

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  screen_name  username  user_id  tweet_id  \
# month
# 5               7             7            7         7        7         7
# 6              10            10           10        10       10        10
# 7              13            13           13        13       13        13
# 8               3             3            3         3        3         3
# 9               7             7            7         7        7         7
# 10              8             8            8         8        8         8
#
#        tweet_url  timestamp  timestamp_epochs  text  ...  video_url  likes  \
# month                                                ...
# 5              7          7                 7     7  ...          0      7
# 6             10         10                10    10  ...          0     10
# 7             13         13                13    13  ...          0     13
# 8              3          3                 3     3  ...          0      3
# 9              7          7                 7     7  ...          0      7
# 10             8          8                 8     8  ...          0      8
#
#        retweets  replies  is_replied  is_reply_to  parent_tweet_id  \
# month
# 5             7        7           7            7                3
# 6            10       10          10           10                5
# 7            13       13          13           13                8
# 8             3        3           3            3                3
# 9             7        7           7            7                1
# 10            8        8           8            8                4
#
#        reply_to_users  classofspeech  senscores
# month
# 5                   7              7          7
# 6                  10             10         10
# 7                  13             13         13
# 8                   3              3          3
# 9                   7              7          7
# 10                  8              8          8
#
# [6 rows x 25 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 5     172
# 6     184
# 7     381
# 8      80
# 9     240
# 10    124
# Name: classofspeech, dtype: int64

# %%
o2=d1[d1['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, screen_name, username, user_id, tweet_id, tweet_url, timestamp, timestamp_epochs, text, text_html, links, hashtags, has_media, img_urls, video_url, likes, retweets, replies, is_replied, is_reply_to, parent_tweet_id, reply_to_users, classofspeech, senscores]
# Index: []
#
# [0 rows x 25 columns]

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  screen_name  username  user_id  tweet_id  \
# month
# 5               7             7            7         7        7         7
# 6              10            10           10        10       10        10
# 7              13            13           13        13       13        13
# 8               3             3            3         3        3         3
# 9               7             7            7         7        7         7
# 10              8             8            8         8        8         8
#
#        tweet_url  timestamp  timestamp_epochs  text  ...  video_url  likes  \
# month                                                ...
# 5              7          7                 7     7  ...          0      7
# 6             10         10                10    10  ...          0     10
# 7             13         13                13    13  ...          0     13
# 8              3          3                 3     3  ...          0      3
# 9              7          7                 7     7  ...          0      7
# 10             8          8                 8     8  ...          0      8
#
#        retweets  replies  is_replied  is_reply_to  parent_tweet_id  \
# month
# 5             7        7           7            7                3
# 6            10       10          10           10                5
# 7            13       13          13           13                8
# 8             3        3           3            3                3
# 9             7        7           7            7                1
# 10            8        8           8            8                4
#
#        reply_to_users  classofspeech  senscores
# month
# 5                   7              7          7
# 6                  10             10         10
# 7                  13             13         13
# 8                   3              3          3
# 9                   7              7          7
# 10                  8              8          8
#
# [6 rows x 25 columns]

# %%
o2=d1[d1['classofspeech']=='offensive_language']
l=len(o2)
abusers=[]
for i in range(l):
    #haters.append(o2.loc[o2.classofspeech=='hate_speech','username'].values[i])
    abusers.append(o2.loc[o2.classofspeech=='offensive_language','screen_name'].values[i])
    #print (o2.loc[o2.classofspeech=='hate_speech','username'].values[i])
abusers
# Out:
# ['jidesalu',
#  'TheThomoHawk',
#  'Tillymint85',
#  'leedargue',
#  'LeighTurbo80',
#  'bigchill_LC',
#  'Coops_tv',
#  'Chartrambler',
#  'Bezean56',
#  'billyboyoh',
#  'StuartBudd1',
#  'cheekylatte',
#  'hull_th',
#  'stuartcairney',
#  'SuperbikeAl',
#  'georgecollie',
#  'Bertie_Wooster',
#  'JackieKane',
#  'Celticanz',
#  'CarolyneKershaw',
#  'RicoS90',
#  'Obscure_Rebel',
#  'letsgowto',
#  'jennymparks',
#  'LeeWrightAddy',
#  'cllrpetemurphy',
#  'GartnerBR',
#  'adamchorley',
#  'hunterathelen',
#  'evans1951',
#  'benjamat10',
#  'usayorkshire',
#  'trickytrev533',
#  'Toxic_Web',
#  'Life_Disrupted',
#  'sven945',
#  'gmckay_51',
#  'ThomasBridge3',
#  'trencherman333',
#  'garyebayliss',
#  'MsLesleySmith',
#  'tvgenius05',
#  'KevinJones26',
#  'sophable',
#  'TheApparatchik',
#  'charlottor',
#  'lynnjackson57',
#  'Life_Disrupted']

# %%
dis=set()
for i in abusers:
    count=0
    for j in o2['screen_name']:
    
        if i==j:
           count+=1 
        if count==2:
            dis.add(j)
            print (count,j)
dis
# Out:
# 2 Life_Disrupted
# 2 Life_Disrupted
# {'Life_Disrupted'}

# %%
sum(o['classofspeech'])
# Out:
# 48

# %%
pero=[]
for i in o['classofspeech']:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero
# Out:
# [14.583333333333334,
#  20.833333333333332,
#  27.083333333333332,
#  6.25,
#  14.583333333333334,
#  16.666666666666668]

# %%
xi=['February','March','April','May','June',"July",'August']

#for i in pero.index:
   # xi.append(i)
yi=[]

for i in pero:
    yi.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yi, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of offensive speech',fontsize=20)
ax.set_title("Percentage of offensive speech in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e8bf958f04c2> in <module>
#       8     yi.append(i)
#       9 fig, ax = plt.subplots(figsize=(15,7))
# ---> 10 plt.bar(xi, yi, edgecolor = 'black', linewidth=2)
#      11
#      12 ax.set_xlabel('Months',fontsize=20)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")

ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#

ax.set_xlabel('Months',fontsize=20)
plt.plot('September',36.170212765957444, markersize=24,marker='X')
plt.plot('November',60, markersize=24,marker='X')

ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive words where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-0a708f18834b> in <module>
#       1 fig, ax = plt.subplots(figsize=(15,7))
# ----> 2 ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")
#       3
#       4 ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#
#       5
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (7,) and (6,)

# %%
pero
# Out:
# [14.583333333333334,
#  20.833333333333332,
#  27.083333333333332,
#  6.25,
#  14.583333333333334,
#  16.666666666666668]

# %%
df=pd.read_csv("input2_threat_tom.csv")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     screen_name  \
# 0             0          5171            5171   _instant_bot_
# 1             1          8750            8750     Giovasummer
# 2             2            39              39       bruce9876
# 3             3          2781            2781  julia_politics
# 4             4          1851            1851       bruce9876
# ..          ...           ...             ...             ...
# 954         954          7210            7210     marciarowe6
# 955         955          5495            5495    simplytiredd
# 956         956          4788            4788   RoseWorthesee
# 957         957          2454            2454   steveffoulkes
# 958         958           705             705  DrKristieLeong
#
#                username              user_id             tweet_id  \
# 0           instant-bot   732647642346491904  1163939417804955654
# 1       Giovanny Verano            168406203  1180611867066163200
# 2       Bruce Bernstein              1765491  1160699664196395009
# 3            Julia ð¶           3438997817  1190367865431633920
# 4       Bruce Bernstein              1765491  1154142728990728192
# ..                  ...                  ...                  ...
# 954              YARDIE            866809320  1167561317491904515
# 955              Evelyn  1150389721010507776  1163889846785662977
# 956                Rose            302378247  1177329717801836544
# 957   steve ffoulkesâ«            355729179  1141085185586413570
# 958  Kristie Leong M.D.            368910785  1170821016106520581
#
#                                       tweet_url            timestamp  \
# 0     /_instant_bot_/status/1163939417804955654  2019-08-20 22:22:36
# 1       /Giovasummer/status/1180611867066163200  2019-10-05 22:32:58
# 2         /bruce9876/status/1160699664196395009  2019-08-11 23:48:59
# 3    /julia_politics/status/1190367865431633920  2019-11-01 20:39:49
# 4         /bruce9876/status/1154142728990728192  2019-07-24 21:34:04
# ..                                          ...                  ...
# 954     /marciarowe6/status/1167561317491904515  2019-08-30 22:14:44
# 955    /simplytiredd/status/1163889846785662977  2019-08-20 19:05:38
# 956   /RoseWorthesee/status/1177329717801836544  2019-09-26 21:10:53
# 957   /steveffoulkes/status/1141085185586413570  2019-06-18 20:48:03
# 958  /DrKristieLeong/status/1170821016106520581  2019-09-08 22:07:37
#
#      timestamp_epochs  ... video_url likes retweets replies  is_replied  \
# 0          1566339756  ...       NaN     0        0       0       False
# 1          1570314778  ...       NaN     4        2       1        True
# 2          1565567339  ...       NaN     0        0       0       False
# 3          1572640789  ...       NaN     0        0       1        True
# 4          1564004044  ...       NaN     1        0       1        True
# ..                ...  ...       ...   ...      ...     ...         ...
# 954        1567203284  ...       NaN     0        0       0       False
# 955        1566327938  ...       NaN    20        0       0       False
# 956        1569532253  ...       NaN     4        0       0       False
# 957        1560890883  ...       NaN     0        0       1        True
# 958        1567980457  ...       NaN     0        0       4        True
#
#     is_reply_to  parent_tweet_id  \
# 0         False              NaN
# 1          True     1.180157e+18
# 2          True     1.160659e+18
# 3          True     1.190360e+18
# 4          True     1.154142e+18
# ..          ...              ...
# 954        True     1.167405e+18
# 955       False              NaN
# 956        True     1.177297e+18
# 957        True     1.140725e+18
# 958        True     1.169590e+18
#
#                                         reply_to_users       classofspeech  \
# 0                                                   []             neither
# 1    [{'screen_name': 'tomwatson', 'user_id': '1049...             neither
# 2    [{'screen_name': 'tomwatson', 'user_id': '1049...             neither
# 3    [{'screen_name': 'GK15513088', 'user_id': '115...             neither
# 4    [{'screen_name': 'tomwatson', 'user_id': '1049...             neither
# ..                                                 ...                 ...
# 954  [{'screen_name': 'tomwatson', 'user_id': '1049...  offensive_language
# 955                                                 []             neither
# 956  [{'screen_name': 'jeremycorbyn', 'user_id': '1...             neither
# 957  [{'screen_name': 'davidivor', 'user_id': '1538...             neither
# 958  [{'screen_name': 'KetoCarnivore', 'user_id': '...             neither
#
#      month
# 0        8
# 1       10
# 2        8
# 3       11
# 4        7
# ..     ...
# 954      8
# 955      8
# 956      9
# 957      6
# 958      9
#
# [959 rows x 26 columns]

# %%
o3=df[df['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o3
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 6               9             9               9            9         9
# 7               8             8               8            8         8
# 8              21            21              21           21        21
# 9               8             8               8            8         8
# 10             19            19              19           19        19
# 11             17            17              17           17        17
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 6            9         9          9          9                 9  ...
# 7            8         8          8          8                 8  ...
# 8           21        21         21         21                21  ...
# 9            8         8          8          8                 8  ...
# 10          19        19         19         19                19  ...
# 11          17        17         17         17                17  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 6             9          0      9         9        9           9            9
# 7             8          0      8         8        8           8            8
# 8            21          0     21        21       21          21           21
# 9             8          0      8         8        8           8            8
# 10           19          0     19        19       19          19           19
# 11           17          0     17        17       17          17           17
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 6                    9               9              9
# 7                    7               8              8
# 8                   21              21             21
# 9                    8               8              8
# 10                  18              19             19
# 11                  17              17             17
#
# [6 rows x 25 columns]

# %%
o33=df[df['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o33
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 9               1             1               1            1         1
# 10              1             1               1            1         1
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 9            1         1          1          1                 1  ...
# 10           1         1          1          1                 1  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 9             1          0      1         1        1           1            1
# 10            1          0      1         1        1           1            1
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 9                    1               1              1
# 10                   1               1              1
#
# [2 rows x 25 columns]

# %%
sum(o3['classofspeech'])
# Out:
# 82

# %%
pero3=[]
for i in o3['classofspeech']:
    ans=i*100/sum(o3['classofspeech'])
    #print (ans)
    pero3.append(ans)
pero3
# Out:
# [10.975609756097562,
#  9.75609756097561,
#  25.609756097560975,
#  9.75609756097561,
#  23.170731707317074,
#  20.73170731707317]

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")

ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#
ax.plot(x1, pero3,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Tom Watson")#

ax.set_xlabel('Months',fontsize=20)
plt.plot('September',36.170212765957444, markersize=24,marker='X')
plt.plot('November',60, markersize=24,marker='X')
plt.plot('November',20.73170731707317, markersize=24,marker='X')

ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive tweets where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-adb6070741b8> in <module>
#       1 fig, ax = plt.subplots(figsize=(15,7))
# ----> 2 ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")
#       3
#       4 ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#
#       5 ax.plot(x1, pero3,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Tom Watson")#
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (7,) and (6,)

# %%
dff=pd.read_csv("input2_threat_Allen.csv")
dff
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0          1073            1073      DylanStrain
# 1              1           856             856  vickylittlewood
# 2              2          1222            1222  mawstrategy2018
# 3              3          3408            3408     Pumpkinpiez1
# 4              4          2250            2250     deletedbyMPs
# ...          ...           ...             ...              ...
# 1292        1292          3945            3945     MichaelGilks
# 1293        1293           669             669       robin_bike
# 1294        1294          2409            2409          pick291
# 1295        1295          2121            2121         mmaher70
# 1296        1296          2232            2232  AlfredToshLines
#
#                              username              user_id  \
# 0     Dylan S ðð¹#JC4PM #Sanders            147602027
# 1                 victoria littlewood           1140436597
# 2                    Michael Williams  1023684405796249600
# 3                          Pumpkinpie            714006801
# 4                   Tweets MPs Delete           1066949670
# ...                               ...                  ...
# 1292                    Michael Gilks             27401066
# 1293                   Robin A Weston   701057298727358468
# 1294                               JR   791122661900443648
# 1295                   michelle maher            322889483
# 1296                             Tosh             20139940
#
#                  tweet_id                                    tweet_url  \
# 0     1072818995932397568      /DylanStrain/status/1072818995932397568
# 1     1037039848379568128  /vickylittlewood/status/1037039848379568128
# 2     1063149334135488513  /mawstrategy2018/status/1063149334135488513
# 3     1090257174163386372     /Pumpkinpiez1/status/1090257174163386372
# 4     1086351495627452419     /deletedbyMPs/status/1086351495627452419
# ...                   ...                                          ...
# 1292  1100496910182424576     /MichaelGilks/status/1100496910182424576
# 1293  1094262562361884675       /robin_bike/status/1094262562361884675
# 1294  1085335886605238272          /pick291/status/1085335886605238272
# 1295  1095286472129871874         /mmaher70/status/1095286472129871874
# 1296  1086635502323802112  /AlfredToshLines/status/1086635502323802112
#
#                 timestamp  timestamp_epochs  ... video_url likes retweets  \
# 0     2018-12-12 11:42:35        1544614955  ...       NaN     2        1
# 1     2018-09-04 18:09:01        1536084541  ...       NaN     1        2
# 2     2018-11-15 19:18:48        1542309528  ...       NaN     0        0
# 3     2019-01-29 14:35:40        1548772540  ...       NaN     0        0
# 4     2019-01-18 19:55:54        1547841354  ...       NaN     0        0
# ...                   ...               ...  ...       ...   ...      ...
# 1292  2019-02-26 20:44:44        1551213884  ...       NaN     0        0
# 1293  2019-02-09 15:51:39        1549727499  ...       NaN     0        0
# 1294  2019-01-16 00:40:14        1547599214  ...       NaN     0        0
# 1295  2019-02-12 11:40:19        1549971619  ...       NaN     5        5
# 1296  2019-01-19 14:44:27        1547909067  ...       NaN    93       21
#
#      replies  is_replied is_reply_to  parent_tweet_id  \
# 0          1        True       False              NaN
# 1          0       False       False              NaN
# 2          0       False        True     1.063035e+18
# 3          0       False       False              NaN
# 4          0       False       False              NaN
# ...      ...         ...         ...              ...
# 1292       0       False        True     1.100185e+18
# 1293       0       False       False              NaN
# 1294       0       False        True     1.085255e+18
# 1295       0       False       False              NaN
# 1296       9        True       False              NaN
#
#                                          reply_to_users  classofspeech  month
# 0                                                    []        neither     12
# 1                                                    []        neither      9
# 2     [{'screen_name': 'Brexshite', 'user_id': '2615...        neither     11
# 3                                                    []        neither      1
# 4                                                    []        neither      1
# ...                                                 ...            ...    ...
# 1292  [{'screen_name': 'AVF_Scooby2000', 'user_id': ...        neither      2
# 1293                                                 []        neither      2
# 1294   [{'screen_name': 'B_HQ', 'user_id': '30051204'}]        neither      1
# 1295                                                 []        neither      2
# 1296                                                 []        neither      1
#
# [1297 rows x 26 columns]

# %%
o4=dff[dff['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o4
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 1              38            38              38           38        38
# 2              14            14              14           14        14
# 9               2             2               2            2         2
# 10             17            17              17           17        17
# 11              8             8               8            8         8
# 12              9             9               9            9         9
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 1           38        38         38         38                38  ...
# 2           14        14         14         14                14  ...
# 9            2         2          2          2                 2  ...
# 10          17        17         17         17                17  ...
# 11           8         8          8          8                 8  ...
# 12           9         9          9          9                 9  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 1            38          0     38        38       38          38           38
# 2            14          0     14        14       14          14           14
# 9             2          0      2         2        2           2            2
# 10           17          0     17        17       17          17           17
# 11            8          0      8         8        8           8            8
# 12            9          0      9         9        9           9            9
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 1                   16              38             38
# 2                    6              14             14
# 9                    2               2              2
# 10                   6              17             17
# 11                   6               8              8
# 12                   6               9              9
#
# [6 rows x 25 columns]

# %%
sum(o3['classofspeech'])
# Out:
# 82

# %%
pero4=[]
for i in o4['classofspeech']:
    ans=i*100/sum(o4['classofspeech'])
    #print (ans)
    pero4.append(ans)
pero4
# Out:
# [43.18181818181818,
#  15.909090909090908,
#  2.272727272727273,
#  19.318181818181817,
#  9.090909090909092,
#  10.227272727272727]

# %%
peero4=[2.272727272727273,
 19.318181818181817,
 9.090909090909092,
 10.227272727272727,43.18181818181818,
 15.909090909090908]
x4=["September 2018",'October 2018','November 2018','December 2018','January 2018','February 2018']

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x4, peero4,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Heidi Allen")


ax.set_xlabel('Months',fontsize=20)

plt.plot('February',15.909090909090908, markersize=24,marker='X')
plt.yticks([0,10,20,30,40,50,60])
ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive words where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".5"})

d1=pd.read_csv("input2_threat.csv",encoding="latin1")
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0           621             621   CluelessTories
# 1              1          4385            4385      goodnitebob
# 2              2          8201            8201     Mr_P_Panther
# 3              3          4562            4562    JeanneBartram
# 4              4          8161            8161    DeannaNolan17
# ...          ...           ...             ...              ...
# 1010        1010          2874            2874      FrankieMac9
# 1011        1011          5500            5500  RhubarbVaselino
# 1012        1012          7399            7399  myerschrismyer1
# 1013        1013          2542            2542  GeordieJoeHardy
# 1014        1014          8235            8235    allanholloway
#
#                                                username              user_id  \
# 0             Citizen Smith - #FBPE5000#RevokeArticle50             44657626
# 1                                           goodnitebob  1064586673722454017
# 2                                      The Pink Panther   944224944170430464
# 3     Spider woman ÃÂ°ÃÂÃÂÃÂ·ÃÂ¯ÃÂ¸ÃÂ #Rev...            555337622
# 4                                          Deanna Nolan  1145426486905712650
# ...                                                 ...                  ...
# 1010                                       Frankie Mac9           4824152675
# 1011                                   Rhubarb Vaselino   849759279271866368
# 1012                                        Chris Myers   865262041103302656
# 1013                 Joe Hardy ÃÂ¢ÃÂÃÂ«ÃÂ¯ÃÂ¸ÃÂ   806113446546853888
# 1014                                           Arthur_S            129594482
#
#                  tweet_id                                    tweet_url  \
# 0     1142693298274017281   /CluelessTories/status/1142693298274017281
# 1     1162654770617868288      /goodnitebob/status/1162654770617868288
# 2     1179437737029574656     /Mr_P_Panther/status/1179437737029574656
# 3     1189669117797777410    /JeanneBartram/status/1189669117797777410
# 4     1179471663311798273    /DeannaNolan17/status/1179471663311798273
# ...                   ...                                          ...
# 1010  1133830545048264704      /FrankieMac9/status/1133830545048264704
# 1011  1148665305150963712  /RhubarbVaselino/status/1148665305150963712
# 1012  1152181227144785920  /myerschrismyer1/status/1152181227144785920
# 1013  1136197416116543488  /GeordieJoeHardy/status/1136197416116543488
# 1014  1179395666717609986    /allanholloway/status/1179395666717609986
#
#                 timestamp  timestamp_epochs  ... video_url likes retweets  \
# 0     2019-06-23 07:18:07        1561274287  ...       NaN    11        0
# 1     2019-08-17 09:17:53        1566033473  ...       NaN     1        0
# 2     2019-10-02 16:47:24        1570034844  ...       NaN     0        0
# 3     2019-10-30 22:23:15        1572474195  ...       NaN     0        0
# 4     2019-10-02 19:02:12        1570042932  ...       NaN     2        3
# ...                   ...               ...  ...       ...   ...      ...
# 1010  2019-05-29 20:20:42        1559161242  ...       NaN     0        0
# 1011  2019-07-09 18:48:44        1562698124  ...       NaN     1        0
# 1012  2019-07-19 11:39:45        1563536385  ...       NaN     0        0
# 1013  2019-06-05 09:05:48        1559725548  ...       NaN     0        0
# 1014  2019-10-02 14:00:13        1570024813  ...       NaN     0        0
#
#      replies  is_replied is_reply_to  parent_tweet_id  \
# 0          0       False        True     1.142680e+18
# 1          0       False        True     1.162394e+18
# 2          0       False        True     1.179431e+18
# 3          0       False        True     1.189460e+18
# 4          0       False       False              NaN
# ...      ...         ...         ...              ...
# 1010       0       False        True     1.133401e+18
# 1011       0       False       False              NaN
# 1012       0       False       False              NaN
# 1013       0       False        True     1.136195e+18
# 1014       0       False        True     1.179391e+18
#
#                                          reply_to_users  classofspeech  month
# 0     [{'screen_name': 'JohnJCrace', 'user_id': '430...        neither      6
# 1     [{'screen_name': 'katcashmeade', 'user_id': '8...        neither      8
# 2     [{'screen_name': 'Jacob_Rees_Mogg', 'user_id':...        neither     10
# 3     [{'screen_name': 'johndante', 'user_id': '2751...        neither     10
# 4                                                    []        neither     10
# ...                                                 ...            ...    ...
# 1010  [{'screen_name': 'kennyzool', 'user_id': '2615...        neither      5
# 1011                                                 []        neither      7
# 1012                                                 []        neither      7
# 1013  [{'screen_name': 'Sillyshib', 'user_id': '8547...        neither      6
# 1014  [{'screen_name': 'allanholloway', 'user_id': '...        neither     10
#
# [1015 rows x 26 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 5     185
# 6     139
# 7     191
# 8     155
# 9     137
# 10    208
# Name: classofspeech, dtype: int64

# %%
d1['classofspeech'].unique()
# Out:
# array(['neither', 'offensive_language', 'hate_speech'], dtype=object)

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  screen_name  username  user_id  tweet_id  \
# month
# 5               7             7            7         7        7         7
# 6              10            10           10        10       10        10
# 7              13            13           13        13       13        13
# 8               3             3            3         3        3         3
# 9               7             7            7         7        7         7
# 10              8             8            8         8        8         8
#
#        tweet_url  timestamp  timestamp_epochs  text  ...  img_urls  video_url  \
# month                                                ...
# 5              7          7                 7     7  ...         7          0
# 6             10         10                10    10  ...        10          0
# 7             13         13                13    13  ...        13          0
# 8              3          3                 3     3  ...         3          0
# 9              7          7                 7     7  ...         7          0
# 10             8          8                 8     8  ...         8          0
#
#        likes  retweets  replies  is_replied  is_reply_to  parent_tweet_id  \
# month
# 5          7         7        7           7            7                3
# 6         10        10       10          10           10                5
# 7         13        13       13          13           13                8
# 8          3         3        3           3            3                3
# 9          7         7        7           7            7                1
# 10         8         8        8           8            8                4
#
#        reply_to_users  classofspeech
# month
# 5                   7              7
# 6                  10             10
# 7                  13             13
# 8                   3              3
# 9                   7              7
# 10                  8              8
#
# [6 rows x 24 columns]

# %%
sum(o['classofspeech'])
# Out:
# 48

# %%
o10=d1[d1['classofspeech']=='offensive_language']
o10
# Out:
#       Unnamed: 0  Unnamed: 0.1      screen_name  \
# 40          1642          1642         jidesalu
# 105         2475          2475     TheThomoHawk
# 114          555           555      Tillymint85
# 117         3671          3671        leedargue
# 141         3933          3933     LeighTurbo80
# 151         2138          2138      bigchill_LC
# 170         1979          1979         Coops_tv
# 196          184           184     Chartrambler
# 199          657           657         Bezean56
# 214          976           976       billyboyoh
# 223         3611          3611      StuartBudd1
# 239         2346          2346      cheekylatte
# 247         3490          3490          hull_th
# 253           52            52    stuartcairney
# 273         3143          3143      SuperbikeAl
# 307          263           263     georgecollie
# 349          238           238   Bertie_Wooster
# 381         2858          2858       JackieKane
# 479         1189          1189        Celticanz
# 482          429           429  CarolyneKershaw
# 538          838           838          RicoS90
# 546         1474          1474    Obscure_Rebel
# 550         2384          2384        letsgowto
# 562          257           257      jennymparks
# 574         1315          1315    LeeWrightAddy
# 577         2379          2379   cllrpetemurphy
# 624         1064          1064        GartnerBR
# 640         3927          3927      adamchorley
# 647         3745          3745    hunterathelen
# 679         3154          3154        evans1951
# 696          468           468       benjamat10
# 729         3262          3262     usayorkshire
# 739         3225          3225    trickytrev533
# 759         2127          2127        Toxic_Web
# 766         1108          1108   Life_Disrupted
# 783         1610          1610          sven945
# 790         1556          1556        gmckay_51
# 826          217           217    ThomasBridge3
# 828         1904          1904   trencherman333
# 840         1350          1350     garyebayliss
# 872         1533          1533    MsLesleySmith
# 908         1149          1149       tvgenius05
# 912         3008          3008     KevinJones26
# 940         1159          1159         sophable
# 954          679           679   TheApparatchik
# 976         2144          2144       charlottor
# 1054        3240          3240    lynnjackson57
# 1180        1089          1089   Life_Disrupted
#
#                                                username              user_id  \
# 40                                            Jide Salu             18726247
# 105                                       Scott Thomson            526247289
# 114                                  Tilly 1 of the 52%   922574269204385792
# 117      Lee Dargue Ã°ÂÂÂ¶ #MentalHealth #DrugsReform             21346129
# 141                                          Turner Lad           4707747395
# 151                                        Big Chill LC           4237630037
# 170   Lorna CooperÃ°ÂÂÂ´Ã³Â ÂÂ§Ã³Â ÂÂ¢Ã³Â ÂÂ¥Ã³...             46611379
# 196                                        Chartrambler            146590158
# 199                               IanL #GTTO #JC4PM2019   731528022076104706
# 214                                    william marshall           1653711962
# 223   Stuart Budd Ã°ÂÂÂ¬Ã°ÂÂÂ§ Ã°ÂÂÂªÃ°ÂÂÂº ...            286332390
# 239   CheekyLatte Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂÂ©Ã¢ÂÂÃ°Â...             83711992
# 247                                              T Hull           3362669200
# 253                                      stuart cairney            234904804
# 273                                       SuperhumbugAl            337626858
# 307                                       George Collie            421750152
# 349                                             Bertram   776738968717160448
# 381                                         Jackie Kane             25671065
# 479   MrCeltic Ã°ÂÂÂªÃ°ÂÂÂºÃ°ÂÂÂ®Ã°ÂÂÂ½Ã°ÂÂ...   869619261840535554
# 482   Carolyne Kershaw Ã°ÂÂÂºÃ°ÂÂÂ¬Ã°ÂÂÂ· Ã°Â...            500102569
# 538   Ã°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂÃ°ÂÂ...            939317322
# 546   Marco Kinney Ã°ÂÂÂ #CorbynOutrider #EngineO...           3004468319
# 550                                       Steve English  1087838216806371330
# 562                                         Jenny Parks             42972275
# 574                                  Ã¦ÂÂÃ¨ÂÂ¾Ã¨Â¿Âª   977974006363185152
# 577                                        Peter Murphy           3314823298
# 624                      ConferÃÂªncias Gartner Brasil            265970282
# 640                                        Adam Chorley             38671422
# 647                                        Helen Hunter            702231159
# 679                                          John Evans            236833383
# 696   Ask yourselfÃ¢ÂÂ Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂÂ¬Ã°Â...            741188732
# 729                                     Damian Gavaghan   823358812627140611
# 739                                        Trickytrev53            852501139
# 759   ÃÂ¢ÃÂ¾ÃÂºÃÂÃÂ¸ÃÂÃÂµÃÂÃÂºÃÂ°ÃÂ Ã...             20686713
# 766                                         Sarah Hurst   889039269637091330
# 783                                                Jack            136027505
# 790                                        Gordon McKay             89681837
# 826                        Openly Gay Ex-Olympic Fencer            619338166
# 828   Steve Ross Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂÂºÃ°ÂÂÂ¸Ã°Â...   938848795600801794
# 840                                        Gary Bayliss           3166073363
# 872                                        lesley smith            125453344
# 908                                    Jonathan Lansana             31888204
# 912                                         Kevin Jones            322624623
# 940                                            Sophie H             49421512
# 954   Lou Read #FBPE+++ Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂÂªÃ°Â...             75862834
# 976                           Magic Money Tree Ã°ÂÂÂ³            313331647
# 1054                                               Lynn           1130798750
# 1180                                        Sarah Hurst   889039269637091330
#
#                  tweet_id                                    tweet_url  \
# 40    1138362776517259264         /jidesalu/status/1138362776517259264
# 105   1127346720344555520     /TheThomoHawk/status/1127346720344555520
# 114   1178925187166855168      /Tillymint85/status/1178925187166855168
# 117   1153689747904172032        /leedargue/status/1153689747904172032
# 141   1153436492922011648     /LeighTurbo80/status/1153436492922011648
# 151   1187010055670910977      /bigchill_LC/status/1187010055670910977
# 170   1189636077369413633         /Coops_tv/status/1189636077369413633
# 196   1186034700697112578     /Chartrambler/status/1186034700697112578
# 199   1165934270222876672         /Bezean56/status/1165934270222876672
# 214   1134909582889799680       /billyboyoh/status/1134909582889799680
# 223   1153909408948269057      /StuartBudd1/status/1153909408948269057
# 239   1127879657272033280      /cheekylatte/status/1127879657272033280
# 247   1154814311090610176          /hull_th/status/1154814311090610176
# 253   1160891829065310208    /stuartcairney/status/1160891829065310208
# 273   1149269927800508417      /SuperbikeAl/status/1149269927800508417
# 307   1132030122264072192     /georgecollie/status/1132030122264072192
# 349   1183357234081947653   /Bertie_Wooster/status/1183357234081947653
# 381   1171190344601493510       /JackieKane/status/1171190344601493510
# 479   1175886481338109952        /Celticanz/status/1175886481338109952
# 482   1142523764598554624  /CarolyneKershaw/status/1142523764598554624
# 538   1168864362615967744          /RicoS90/status/1168864362615967744
# 546   1143214656913313793    /Obscure_Rebel/status/1143214656913313793
# 550   1127816862773985281        /letsgowto/status/1127816862773985281
# 562   1132045701268086786      /jennymparks/status/1132045701268086786
# 574   1145326441787265024    /LeeWrightAddy/status/1145326441787265024
# 577   1127829322352549888   /cllrpetemurphy/status/1127829322352549888
# 624   1134059504088145923        /GartnerBR/status/1134059504088145923
# 640   1153440168621281286      /adamchorley/status/1153440168621281286
# 647   1153613299768074241    /hunterathelen/status/1153613299768074241
# 679   1149261717039407104        /evans1951/status/1149261717039407104
# 696   1142415121605713920       /benjamat10/status/1142415121605713920
# 729   1149078935772073984     /usayorkshire/status/1149078935772073984
# 739   1149177247384899589    /trickytrev533/status/1149177247384899589
# 759   1187672113328599042        /Toxic_Web/status/1187672113328599042
# 766   1176079783664529408   /Life_Disrupted/status/1176079783664529408
# 783   1138418342841204736          /sven945/status/1138418342841204736
# 790   1138862861931962368        /gmckay_51/status/1138862861931962368
# 826   1184788300646752256    /ThomasBridge3/status/1184788300646752256
# 828   1150113326925537280   /trencherman333/status/1150113326925537280
# 840   1144962816652259328     /garyebayliss/status/1144962816652259328
# 872   1139053118816235521    /MsLesleySmith/status/1139053118816235521
# 908   1175891425906626561       /tvgenius05/status/1175891425906626561
# 912   1149511035604238337     /KevinJones26/status/1149511035604238337
# 940   1175889729956524035         /sophable/status/1175889729956524035
# 954   1165747978021277698   /TheApparatchik/status/1165747978021277698
# 976   1186970417619197953       /charlottor/status/1186970417619197953
# 1054  1149096582937288705    /lynnjackson57/status/1149096582937288705
# 1180  1176079783664529408   /Life_Disrupted/status/1176079783664529408
#
#                 timestamp  timestamp_epochs  \
# 40    2019-06-11 08:30:10        1560241810
# 105   2019-05-11 22:56:17        1557615377
# 114   2019-10-01 06:50:42        1569912642
# 117   2019-07-23 15:34:05        1563896045
# 141   2019-07-22 22:47:44        1563835664
# 151   2019-10-23 14:17:05        1571840225
# 170   2019-10-30 20:11:57        1572466317
# 196   2019-10-20 21:41:22        1571607682
# 199   2019-08-26 10:29:26        1566815366
# 214   2019-06-01 19:48:24        1559418504
# 223   2019-07-24 06:06:56        1563948416
# 239   2019-05-13 10:13:59        1557742439
# 247   2019-07-26 18:02:41        1564164161
# 253   2019-08-12 12:32:35        1565613155
# 273   2019-07-11 10:51:17        1562842277
# 307   2019-05-24 21:06:27        1558731987
# 349   2019-10-13 12:22:04        1570969324
# 381   2019-09-09 22:35:12        1568068512
# 479   2019-09-22 21:35:58        1569188158
# 482   2019-06-22 20:04:27        1561233867
# 538   2019-09-03 12:32:35        1567513955
# 546   2019-06-24 17:49:48        1561398588
# 550   2019-05-13 06:04:28        1557727468
# 562   2019-05-24 22:08:22        1558735702
# 574   2019-06-30 13:41:17        1561902077
# 577   2019-05-13 06:53:59        1557730439
# 624   2019-05-30 11:30:30        1559215830
# 640   2019-07-22 23:02:20        1563836540
# 647   2019-07-23 10:30:18        1563877818
# 679   2019-07-11 10:18:40        1562840320
# 696   2019-06-22 12:52:44        1561207964
# 729   2019-07-10 22:12:21        1562796741
# 739   2019-07-11 04:43:01        1562820181
# 759   2019-10-25 10:07:52        1571998072
# 766   2019-09-23 10:24:05        1569234245
# 783   2019-06-11 12:10:58        1560255058
# 790   2019-06-12 17:37:19        1560361039
# 826   2019-10-17 11:08:37        1571310517
# 828   2019-07-13 18:42:39        1563043359
# 840   2019-06-29 13:36:22        1561815382
# 872   2019-06-13 06:13:20        1560406400
# 908   2019-09-22 21:55:37        1569189337
# 912   2019-07-12 02:49:22        1562899762
# 940   2019-09-22 21:48:53        1569188933
# 954   2019-08-25 22:09:11        1566770951
# 976   2019-10-23 11:39:35        1571830775
# 1054  2019-07-10 23:22:29        1562800949
# 1180  2019-09-23 10:24:05        1569234245
#
#                                                    text  ... video_url likes  \
# 40    On Boris Johnson\n\nÃ¢ÂÂIt will be pretty he...  ...       NaN     3
# 105   Alan DuncanÃ¢ÂÂs little smug, delighted face...  ...       NaN     3
# 114   He does...They all  do ... his minion Alan Dun...  ...       NaN     8
# 117   I mean, say what you will about Alan Duncan, b...  ...       NaN     1
# 141   With all due respect. But what the fuck would ...  ...       NaN     0
# 151   You should meet my local dental receptionists!...  ...       NaN     1
# 170   Nicky Morgan, Amber Rudd, Sir David Lidington,...  ...       NaN   306
# 196   Nigel Farage doesn't....Alan Duncan does\n\nHe...  ...       NaN     1
# 199   Alan Duncan has a long history of being a Ã¢Â...  ...       NaN     2
# 214   For balance you should also listen to the Joan...  ...       NaN     0
# 223   Remaining in the EU isn't over.\n\nIt's so obv...  ...       NaN   126
# 239   My god Alan Duncan, deluded member of the fail...  ...       NaN   105
# 247   Thats deriliction of duty she doesnt care abou...  ...       NaN     1
# 253   Tried to send you a daily record artical about...  ...       NaN     0
# 273   So what ?\nAlan Duncan is an unprincipled pric...  ...       NaN     3
# 307   All remainer together. Just like Alan Duncan w...  ...       NaN     0
# 349   1. Tories and Lib Dems called the referendum.\...  ...       NaN    19
# 381   Oh look, Alan Duncan giving it Orwell. The fix...  ...       NaN    51
# 479   #toriesatwar Alan Duncan watching Theresa's re...  ...       NaN    15
# 482   Re-watching the BBC's Brexit: A Very British C...  ...       NaN     0
# 538   Did I just hear Alan Duncan say, that we have ...  ...       NaN     0
# 546   Errm ..Sir Alan Duncan MP\nÃ¢ÂÂHeÃ¢ÂÂs [#B...  ...       NaN     2
# 550           Alan Duncan you are frigging deluded man.  ...       NaN     0
# 562   MayÃ¢ÂÂs 2017 election campaign failed in pa...  ...       NaN     3
# 574                                 who is alan duncan?  ...       NaN     0
# 577   That's how Alan Duncan and his mates have got ...  ...       NaN     0
# 624   Alan Duncan apresenta no #GartnerDA uma visÃÂ...  ...       NaN     1
# 640   Why the fuck is Alan Duncan an Knight of the r...  ...       NaN     0
# 647   You could always ask Alan Duncan. Well you cou...  ...       NaN     1
# 679   CanÃ¢ÂÂt wait for Boris to sack that twat Al...  ...       NaN     0
# 696   Tory Toy boy multi millionaire Alan Duncan got...  ...       NaN     1
# 729   This is so politicised around Brexit. Alan Dun...  ...       NaN     1
# 739   Alan Duncan your a disgrace not Boris Johnson ...  ...       NaN     0
# 759   Fucking up his Christmas... he's appearing in ...  ...       NaN     0
# 766   Alan Duncan earlier this year: "It's another d...  ...       NaN    12
# 783   IÃ¢ÂÂd take great pleasure in punching Alan ...  ...       NaN     0
# 790   More to the point, Alan Duncan rubbished her b...  ...       NaN     2
# 826   What about May loyalists in the party who agre...  ...       NaN     1
# 828   Here's a recent photo of the real "HMS Alan Du...  ...       NaN     1
# 840   Sir Alan Duncan, how the Fuck did he get that,...  ...       NaN     0
# 872   And Alan Duncan has made it clear that the sto...  ...       NaN     1
# 908   #ToriesAtWar makes you wonder does Alan Duncan...  ...       NaN     0
# 912   The two biggest snakes in the conservative gov...  ...       NaN     0
# 940   Fuckinghell.  Alan Duncan on this doc is fucki...  ...       NaN     8
# 954   Not sure if I misunderstand the tweet but as m...  ...       NaN     1
# 976         Alan Duncan can absolutely get fucked #PMQs  ...       NaN     1
# 1054  What does that say about Alan Duncan - a despi...  ...       NaN     0
# 1180  Alan Duncan earlier this year: "It's another d...  ...       NaN    12
#
#      retweets  replies is_replied  is_reply_to  parent_tweet_id  \
# 40          1        1       True        False              NaN
# 105         0        1       True         True     1.127336e+18
# 114         6        1       True         True     1.172951e+18
# 117         0        0      False        False              NaN
# 141         0        0      False         True     1.153270e+18
# 151         0        0      False         True     1.187006e+18
# 170        50        9       True        False              NaN
# 196         1        0      False         True     1.186031e+18
# 199         0        0      False         True     1.165927e+18
# 214         0        0      False        False              NaN
# 223        45        3       True         True     1.153791e+18
# 239        39       14       True        False              NaN
# 247         0        0      False         True     1.154682e+18
# 253         0        0      False         True     1.160584e+18
# 273         0        0      False        False              NaN
# 307         0        0      False         True     1.132024e+18
# 349         8        3       True        False              NaN
# 381        18        2       True        False              NaN
# 479         2        0      False        False              NaN
# 482         0        0      False        False              NaN
# 538         0        0      False         True     1.168863e+18
# 546         0        0      False         True     1.143094e+18
# 550         0        0      False         True     1.127664e+18
# 562         0        1       True        False              NaN
# 574         0        0      False         True     1.145135e+18
# 577         0        0      False        False              NaN
# 624         0        0      False        False              NaN
# 640         0        0      False         True     1.153306e+18
# 647         0        0      False        False              NaN
# 679         0        0      False        False              NaN
# 696         0        0      False        False              NaN
# 729         0        1       True         True     1.148939e+18
# 739         0        0      False         True     1.149046e+18
# 759         1        0      False        False              NaN
# 766         6        0      False        False              NaN
# 783         0        1       True         True     1.138359e+18
# 790         0        0      False        False              NaN
# 826         0        1       True         True     1.184788e+18
# 828         0        0      False         True     1.149714e+18
# 840         0        0      False         True     1.144899e+18
# 872         0        0      False         True     1.138798e+18
# 908         1        1       True        False              NaN
# 912         0        0      False        False              NaN
# 940         0        1       True        False              NaN
# 954         0        1       True         True     1.165714e+18
# 976         0        0      False        False              NaN
# 1054        0        0      False         True     1.148942e+18
# 1180        6        0      False        False              NaN
#
#                                          reply_to_users       classofspeech  \
# 40                                                   []  offensive_language
# 105   [{'screen_name': 'DouglasCarswell', 'user_id':...  offensive_language
# 114   [{'screen_name': 'TarkaRoshe', 'user_id': '224...  offensive_language
# 117                                                  []  offensive_language
# 141   [{'screen_name': 'MartinDaubney', 'user_id': '...  offensive_language
# 151   [{'screen_name': 'Sozzinski', 'user_id': '7196...  offensive_language
# 170                                                  []  offensive_language
# 196   [{'screen_name': 'allisonpearson', 'user_id': ...  offensive_language
# 199   [{'screen_name': 'KazzJenkins', 'user_id': '25...  offensive_language
# 214                                                  []  offensive_language
# 223   [{'screen_name': 'BBCNewsnight', 'user_id': '2...  offensive_language
# 239                                                  []  offensive_language
# 247   [{'screen_name': 'Lstedmanbryce', 'user_id': '...  offensive_language
# 253   [{'screen_name': 'BillyPTSD', 'user_id': '1082...  offensive_language
# 273                                                  []  offensive_language
# 307   [{'screen_name': 'BBCNewsnight', 'user_id': '2...  offensive_language
# 349                                                  []  offensive_language
# 381                                                  []  offensive_language
# 479                                                  []  offensive_language
# 482                                                  []  offensive_language
# 538   [{'screen_name': 'oenanthe54', 'user_id': '593...  offensive_language
# 546   [{'screen_name': 'lunaperla', 'user_id': '1411...  offensive_language
# 550   [{'screen_name': 'lucyallan', 'user_id': '1613...  offensive_language
# 562                                                  []  offensive_language
# 574   [{'screen_name': 'MatthewStadlen', 'user_id': ...  offensive_language
# 577                                                  []  offensive_language
# 624                                                  []  offensive_language
# 640   [{'screen_name': 'bbclaurak', 'user_id': '6118...  offensive_language
# 647                                                  []  offensive_language
# 679                                                  []  offensive_language
# 696                                                  []  offensive_language
# 729   [{'screen_name': 'eliesian', 'user_id': '76980...  offensive_language
# 739   [{'screen_name': 'SkyNews', 'user_id': '758703...  offensive_language
# 759                                                  []  offensive_language
# 766                                                  []  offensive_language
# 783   [{'screen_name': 'Mowgzilla', 'user_id': '1288...  offensive_language
# 790                                                  []  offensive_language
# 826   [{'screen_name': 'jonworth', 'user_id': '17442...  offensive_language
# 828   [{'screen_name': 'AlanDuncanMP', 'user_id': '1...  offensive_language
# 840   [{'screen_name': 'andywigmore', 'user_id': '33...  offensive_language
# 872   [{'screen_name': 'Sandbach', 'user_id': '92759...  offensive_language
# 908                                                  []  offensive_language
# 912                                                  []  offensive_language
# 940                                                  []  offensive_language
# 954   [{'screen_name': 'HeleneMidhurst', 'user_id': ...  offensive_language
# 976                                                  []  offensive_language
# 1054  [{'screen_name': 'wallaceme', 'user_id': '3237...  offensive_language
# 1180                                                 []  offensive_language
#
#       month
# 40        6
# 105       5
# 114      10
# 117       7
# 141       7
# 151      10
# 170      10
# 196      10
# 199       8
# 214       6
# 223       7
# 239       5
# 247       7
# 253       8
# 273       7
# 307       5
# 349      10
# 381       9
# 479       9
# 482       6
# 538       9
# 546       6
# 550       5
# 562       5
# 574       6
# 577       5
# 624       5
# 640       7
# 647       7
# 679       7
# 696       6
# 729       7
# 739       7
# 759      10
# 766       9
# 783       6
# 790       6
# 826      10
# 828       7
# 840       6
# 872       6
# 908       9
# 912       7
# 940       9
# 954       8
# 976      10
# 1054      7
# 1180      9
#
# [48 rows x 25 columns]

# %%
usertweets = o10.groupby('username')
#Taking the top 25 tweeting users
top_users = usertweets.count()['text'].sort_values(ascending = False)[:25]
top_users_dict = top_users.to_dict()
user_ordered_dict =sorted(top_users_dict.items(), key=lambda x:x[1])
user_ordered_dict = user_ordered_dict[::-1]
#Now, like in the previous hashtags and mention cases, going to make #two lists, one with the username and one with the value
dict_values = []
dict_keys = []
for item in user_ordered_dict[0:25]:
    dict_keys.append(item[0])
    dict_values.append(item[1])

# %%
fig = plt.figure(figsize = (15,9))
index = np.arange(25)
plt.bar(index, dict_values, edgecolor = 'black', linewidth=1)
plt.xlabel('Most active Users', fontsize = 18)
plt.ylabel('No of Tweets', fontsize=20)
plt.xticks(index,dict_keys, fontsize=15, rotation=80)
plt.title('Number of tweets for the most active users', fontsize = 20)
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 155 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 155 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import requests
x=d1['text']
no_neg=[]
no_pos=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/article_stats/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    if response.status_code==200:
      #print (jsonobj['number_negative_words'])
      no_neg.append(jsonobj['number_negative_words'])
      print (jsonobj['number_positive_words'])
      no_pos.append(jsonobj['number_positive_words'])
    else:     

      no_neg.append(0)
      #print (jsonobj['number_of_words'])
      no_pos.append(0)
# Out:
# 0
# 2
# 0
# 0
# 1
# 0
# 0
# 2
# 0
# 1
# 2
# 1
# 0
# 0
# 0
# 1
# 1
# 4
# 1
# 0
# 0
# 0
# 2
# 0
# 1
# 0
# 0
# 2
# 1
# 0
# 0
# 1
# 0
# 0
# 2
# 2
# 0
# 0
# 2
# 4
# 0
# 3
# 2
# 1
# 0
# 1
# 2
# 3
# 5
# 0
# 1
# 1
# 0
# 0
# 0
# 0
# 2
# 0
# 0
# 0
# 0
# 1
# 0
# 0
# 2
# 2
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# 2
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 0
# 1
# 1
# 0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# OSError: [WinError 10051] A socket operation was attempted to an unreachable network
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ProtocolError: ('Connection aborted.', OSError(10051, 'A socket operation was attempted to an unreachable network', None, 10051, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-397c5009f572> in <module>
#       4 no_pos=[]
#       5 for i in x:
# ----> 6     response=requests.get(f'http://104.248.174.180/article_stats/?query={i}')
#       7     #print(response.json())
#       8     jsonobj=response.json()
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError(10051, 'A socket operation was attempted to an unreachable network', None, 10051, None))

# %%
d1['negativewords']=no_neg
d1['positivewords']=no_pos
d1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".6"})

df=pd.read_csv("negpos Alanduncan.csv",encoding="latin1")
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0          1593            1593     JimPickworth
# 1              1           465             465      PixieSteven
# 2              2          1615            1615            G3JKL
# 3              3           490             490      Dr_Theodora
# 4              4          1926            1926    Johnallsopp12
# ...          ...           ...             ...              ...
# 1176        1176          3173            3173        JRLHarris
# 1177        1177          3717            3717  Michael71116154
# 1178        1178           111             111     MattGunner32
# 1179        1179          2310            2310     BrexitLondon
# 1180        1180          1089            1089   Life_Disrupted
#
#                                                username              user_id  \
# 0                                           jimbobags67            946852621
# 1     #CatsofDurham PRINCESS AND THOMAS #FindMissing...   810773762362707968
# 2                                           John Lovell             20597212
# 3                                     Theodora Christou           1324666688
# 4               THE NORTHERNER Ã°ÂÂÂ¬Ã°ÂÂÂ§Ã°ÂÂ¤Âª  1096481855111655424
# ...                                                 ...                  ...
# 1176                     Joseph Harris Ã°ÂÂÂªÃ°ÂÂÂº           4203800363
# 1177                                      Michael Watts   914534354948444165
# 1178                                       MattGunner32            334869752
# 1179                                PeterThompsonLondon   836721050008313857
# 1180                                        Sarah Hurst   889039269637091330
#
#                  tweet_id                                    tweet_url  \
# 0     1138545291156697088     /JimPickworth/status/1138545291156697088
# 1     1142415909996441600      /PixieSteven/status/1142415909996441600
# 2     1138415257381212160            /G3JKL/status/1138415257381212160
# 3     1141100396913598474      /Dr_Theodora/status/1141100396913598474
# 4     1149961723862011904    /Johnallsopp12/status/1149961723862011904
# ...                   ...                                          ...
# 1176  1149245960415064066        /JRLHarris/status/1149245960415064066
# 1177  1153634076143816709  /Michael71116154/status/1153634076143816709
# 1178  1156937695362465793     /MattGunner32/status/1156937695362465793
# 1179  1128031636103335936     /BrexitLondon/status/1128031636103335936
# 1180  1176079783664529408   /Life_Disrupted/status/1176079783664529408
#
#                 timestamp  timestamp_epochs  ... retweets replies is_replied  \
# 0     2019-06-11 20:35:25        1560285325  ...        0       0      False
# 1     2019-06-22 12:55:52        1561208152  ...        2       0      False
# 2     2019-06-11 11:58:42        1560254322  ...        1       0      False
# 3     2019-06-18 21:48:29        1560894509  ...        3       3       True
# 4     2019-07-13 08:40:14        1563007214  ...        0       0      False
# ...                   ...               ...  ...      ...     ...        ...
# 1176  2019-07-11 09:16:03        1562836563  ...        0       2       True
# 1177  2019-07-23 11:52:51        1563882771  ...        0       0      False
# 1178  2019-08-01 14:40:16        1564670416  ...        0       0      False
# 1179  2019-05-13 20:17:54        1557778674  ...        0       0      False
# 1180  2019-09-23 10:24:05        1569234245  ...        6       0      False
#
#      is_reply_to  parent_tweet_id  \
# 0           True     1.138359e+18
# 1          False              NaN
# 2           True     1.138413e+18
# 3          False              NaN
# 4           True     1.149308e+18
# ...          ...              ...
# 1176       False              NaN
# 1177        True     1.153319e+18
# 1178        True     1.156933e+18
# 1179       False              NaN
# 1180       False              NaN
#
#                                          reply_to_users       classofspeech  \
# 0     [{'screen_name': 'tomcopley', 'user_id': '1347...             neither
# 1                                                    []             neither
# 2     [{'screen_name': 'LeaveEUOfficial', 'user_id':...             neither
# 3                                                    []             neither
# 4     [{'screen_name': 'TheFogeys', 'user_id': '7200...             neither
# ...                                                 ...                 ...
# 1176                                                 []             neither
# 1177  [{'screen_name': 'Peston', 'user_id': '1415713...             neither
# 1178  [{'screen_name': 'IainDale', 'user_id': '58380...             neither
# 1179                                                 []             neither
# 1180                                                 []  offensive_language
#
#       month  negativewords  positivewords
# 0         6              0              0
# 1         6              0              2
# 2         6              0              0
# 3         6              0              0
# 4         7              0              1
# ...     ...            ...            ...
# 1176      7              0              3
# 1177      7              0              0
# 1178      8              0              0
# 1179      5              0              0
# 1180      9              1              0
#
# [1181 rows x 28 columns]

# %%
kplus=df.groupby('month',sort=True)['positivewords'].sum()
kplus
# Out:
# month
# 5     108
# 6     136
# 7     239
# 8      80
# 9     170
# 10    102
# Name: positivewords, dtype: int64

# %%
#kplusm=df.groupby('month',sort=True)['positivewords'].mean()
#kplusm
# Out:
# month
# 5     0.627907
# 6     0.739130
# 7     0.627297
# 8     1.000000
# 9     0.708333
# 10    0.822581
# Name: positivewords, dtype: float64

# %%
kneg=df.groupby('month',sort=True)['negativewords'].sum()
kneg
# Out:
# month
# 5      85
# 6     112
# 7     219
# 8      33
# 9     102
# 10     56
# Name: negativewords, dtype: int64
