# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".7"})

d=pd.read_csv("Mark1ann.csv",encoding="latin1")
len(d)
# Out:
# 702

# %%
d['month']=d['timestamp'].apply(lambda x :x[0:2])
d
# Out:
#      Unnamed: 0  Unnamed: 0.1      screen_name         username       user_id  \
# 0             0             0  mmollymoonshine  Moonshine Molly  5.728513e+07
# 1             1             1  mmollymoonshine  Moonshine Molly  5.728513e+07
# 2             2             2     iainastewart     Iain Stewart  1.002608e+08
# 3             3             3         FTusa284     Francis Tusa  2.754353e+08
# 4             4             4           ric_mk  Ric Brackenbury  3.371353e+08
# ..          ...           ...              ...              ...           ...
# 697         697           697   DavidLewis1952      David Lewis  1.985974e+08
# 698         698           698     HungryHatter            Simon  2.294790e+07
# 699         699           699   DavidLewis1952      David Lewis  1.985974e+08
# 700         700           700      AmIRightSir        Mr Memory  3.242493e+09
# 701         701           701    Craig_Lewis77      Craig Lewis  2.351174e+08
#
# ...

# %%
b1z=d.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 10    104
# 11    229
# 6/     70
# 7/    142
# 8/     75
# 9/     82
# Name: classofspeech, dtype: int64

# %%
o=d[d['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  screen_name  username  user_id  tweet_id  \
# month
# 10              2             2            2         2        2         2
# 11              3             3            3         3        3         3
#
#        tweet_url  timestamp  timestamp_epochs  text  ...  img_urls  video_url  \
# month                                                ...
# 10             2          2                 2     2  ...         2          0
# 11             3          3                 3     3  ...         3          0
#
#        likes  retweets  replies  is_replied  is_reply_to  parent_tweet_id  \
# month
# 10         2         2        2           2            2                2
# 11         3         3        3           3            3                1
#
#        reply_to_users  classofspeech
# month
# 10                  2              2
# 11                  3              3
#
# [2 rows x 24 columns]

# %%
len(d[d['classofspeech']=='offensive_language'])
# Out:
# 5

# %%
sum(o['classofspeech'])
# Out:
# 5

# %%
pero=[]
for i in o['classofspeech']:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero
# Out:
# [40.0, 60.0]

# %%
x1=['June','July','August','September','October','November']
y1=[0,0,0,0,40,60]
