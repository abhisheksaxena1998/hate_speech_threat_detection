# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".6"})

d1=pd.read_csv("final Nicky Morgan.csv",encoding="latin1")
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0          1703            1703      Rhiskiboi91
# 1              1          5449            5449         eliesian
# 2              2          5058            5058    Theatremusing
# 3              3          1149            1149     dianas_house
# 4              4           432             432     PennoftheNth
# ...          ...           ...             ...              ...
# 2496        2496          1113            1113  Chester66666666
# 2497        2497          3340            3340   oliviawood0706
# 2498        2498          1552            1552         Tonyhd16
# 2499        2499          5337            5337   craftybookworm
# 2500        2500          4668            4668  kathryninstereo
#
#                                                username              user_id  \
# 0     RÃÂÃÂ­an ÃÂÃÂ' Catharnaigh ÃÂ°ÃÂÃÂ...            333098431
# 1                                             Iain Lees   769802145726132224
# 2                                        Theatremusings   719706176649342977
# 3                                  Diane House Woodcock             22316199
# 4                                                 penny  1072947262781882368
# ...                                                 ...                  ...
# 2496                          ChesterCharlie6 Red #FBPE           1399929349
# 2497                                    hopeinthefuture           1853730362
# 2498                                             Tonyhd  1070714172726501377
# 2499                                Nicola ÃÂ¢ÃÂÃÂ             30026482
# 2500                                 Kathryn Cartwright             20906661
#
#                  tweet_id                                    tweet_url  \
# 0     1139278652401770496      /Rhiskiboi91/status/1139278652401770496
# 1     1174627552964546562         /eliesian/status/1174627552964546562
# 2     1154373272403927040    /Theatremusing/status/1154373272403927040
# 3     1123989924431257602     /dianas_house/status/1123989924431257602
# 4     1156793825567920128     /PennoftheNth/status/1156793825567920128
# ...                   ...                                          ...
# 2496  1125282960469630976  /Chester66666666/status/1125282960469630976
# 2497  1189662771228659712   /oliviawood0706/status/1189662771228659712
# 2498  1131232280905691136         /Tonyhd16/status/1131232280905691136
# 2499  1175890233046568960   /craftybookworm/status/1175890233046568960
# 2500  1180588812302348289  /kathryninstereo/status/1180588812302348289
#
#                 timestamp  timestamp_epochs  ... video_url likes retweets  \
# 0     2019-06-13 21:09:32        1560460172  ...       NaN     2        0
# 1     2019-09-19 10:13:26        1568888006  ...       NaN     0        0
# 2     2019-07-25 12:50:10        1564059010  ...       NaN     0        0
# 3     2019-05-02 16:37:35        1556815055  ...       NaN     0        1
# 4     2019-08-01 05:08:34        1564636114  ...       NaN     0        0
# ...                   ...               ...  ...       ...   ...      ...
# 2496  2019-05-06 06:15:39        1557123339  ...       NaN     1        1
# 2497  2019-10-30 21:58:02        1572472682  ...       NaN     0        0
# 2498  2019-05-22 16:16:07        1558541767  ...       NaN     1        0
# 2499  2019-09-22 21:50:53        1569189053  ...       NaN     1        0
# 2500  2019-10-05 21:01:21        1570309281  ...       NaN     4        0
#
#      replies  is_replied is_reply_to  parent_tweet_id  \
# 0          0       False        True     1.139135e+18
# 1          0       False       False              NaN
# 2          0       False       False              NaN
# 3          0       False       False              NaN
# 4          0       False       False              NaN
# ...      ...         ...         ...              ...
# 2496       0       False        True     1.125045e+18
# 2497       0       False        True     1.189638e+18
# 2498       0       False        True     1.131231e+18
# 2499       0       False       False              NaN
# 2500       0       False       False              NaN
#
#                                          reply_to_users       classofspeech  \
# 0     [{'screen_name': 'ainefromderry', 'user_id': '...             neither
# 1                                                    []             neither
# 2                                                    []             neither
# 3                                                    []             neither
# 4                                                    []             neither
# ...                                                 ...                 ...
# 2496  [{'screen_name': 'lazaroumterror', 'user_id': ...             neither
# 2497  [{'screen_name': 'BrexitBetrayed', 'user_id': ...             neither
# 2498  [{'screen_name': 'bbclaurak', 'user_id': '6118...             neither
# 2499                                                 []  offensive_language
# 2500                                                 []             neither
#
#       month
# 0         6
# 1         9
# 2         7
# 3         5
# 4         8
# ...     ...
# 2496      5
# 2497     10
# 2498      5
# 2499      9
# 2500     10
#
# [2501 rows x 26 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 5     273
# 6     316
# 7     337
# 8     181
# 9     630
# 10    764
# Name: classofspeech, dtype: int64

# %%
d1['classofspeech'].unique()
# Out:
# array(['neither', 'offensive_language'], dtype=object)

# %%
o1=d1[d1['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, screen_name, username, user_id, tweet_id, tweet_url, timestamp, timestamp_epochs, text, text_html, links, hashtags, has_media, img_urls, video_url, likes, retweets, replies, is_replied, is_reply_to, parent_tweet_id, reply_to_users, classofspeech]
# Index: []
#
# [0 rows x 25 columns]

# %%
o2=d1[d1['classofspeech']=='offensive_language']
l=len(o2)
abusers=[]
for i in range(l):
    #haters.append(o2.loc[o2.classofspeech=='hate_speech','username'].values[i])
    abusers.append(o2.loc[o2.classofspeech=='offensive_language','screen_name'].values[i])
    #print (o2.loc[o2.classofspeech=='hate_speech','username'].values[i])
abusers
# Out:
# ['DaveJH4',
#  'coone_michael',
#  'lauran1902',
#  'steven_t_green',
#  'richardSuncarr',
#  'DGAll41',
#  'RachelG21879460',
#  'Smartyman',
#  'GillW1220',
#  'Della631',
#  'YesYes2Yes',
#  'nevetssnilloc',
#  '67Snowy',
#  'richardyjones',
#  'Box_Boy99',
#  'theparkerilla',
#  'RawdonCrozier',
#  'BagladyM',
#  'gpratt21',
#  'LondonEconomic',
#  'peterpalmer901',
#  'DavidL1980',
#  'geoffreyMyers1',
#  'george19a',
#  'RJMrgn',
#  'goldfinchgazer',
#  'Erwhatdidyousay',
#  'AuntyLush',
#  'FidelCuntstruck',
#  'NickyMorgan__',
#  'nickcorston',
#  'YourFriendZippy',
#  'peterpalmer901',
#  'CarolineCreator',
#  'Hargraver',
#  'LeftLeftfooter',
#  'Pibasedlifeform',
#  'christill',
#  'MarkWelshpool',
#  'Patrick10599096',
#  'BSAboarding',
#  'harrisimo',
#  'guyevan29068996',
#  'harrisimo',
#  'StMichael888',
#  'LandanTownRyan',
#  'akazeeox',
#  'Mr_NG_Photo',
#  'AleexxJP',
#  'philiparrogers',
#  'Coops_tv',
#  'Jayphex303',
#  'mulsah1978',
#  'WxmJackoLa',
#  'BeatsSurrender',
#  'StuartDPlunkett',
#  'FrenchyStu',
#  'MCarrielies',
#  'MichaelKirkbri5',
#  'wardmajor',
#  'garymca66',
#  'mrneilmorrow',
#  'lilyk1000',
#  'Magman55',
#  'RtHonTwatness',
#  'namaste66ahimsa',
#  'Juliaarthur8',
#  'richiecarey35',
#  'Kat_Says_Stuff',
#  'stillbestest',
#  'BUDDHA_DRAGON1',
#  'ibrook1',
#  'PederDray',
#  'DilynThe',
#  '180_180_141',
#  'thetree_man',
#  'MCarrielies',
#  '_Harry_Brennan_',
#  'rosskcameron',
#  'mashleybrown',
#  'Annette1Hardy',
#  'MarianSwetman',
#  'Sportydoodle',
#  'lancastrian99',
#  'pchallinor',
#  'StuartWelsh4',
#  'Hayes3344',
#  'SuffolkCoastLab',
#  'DistilledWill',
#  'joelashbridge',
#  'GRALambo',
#  'poolton_portia',
#  'steve_hawkes',
#  'Michex69',
#  'LandanTownRyan',
#  'namaste66ahimsa',
#  'Youth4ia',
#  'Bobbiej90572948',
#  'Rock_1878',
#  'MCarrielies',
#  'AnthonyStanbury',
#  'dontreallyuse79',
#  'orangeorangeboy',
#  'Lokster71',
#  'ffiniol14',
#  'PUPartyUK',
#  'Farrel_Raven',
#  'ely_peddler',
#  'IconoDesignUK',
#  'sallywilts',
#  'Nat__Wil',
#  'syerph',
#  'exasperated55',
#  'Wendysing',
#  'Athena6931',
#  'BridgeeCee',
#  'rorysalad',
#  'Juliaarthur8',
#  'matteusroberts',
#  'LadyZaichik',
#  'MsTropey',
#  'pipspeaker',
#  'cococupcakeice',
#  'CarolineCreator',
#  'TomHulme79',
#  'grahamlithgow',
#  'peterpalmer901',
#  'sarah_stook',
#  'DavidMagicsmith',
#  'TQGEssex',
#  'MCarrielies',
#  'stephentrew',
#  'the_middle_bit',
#  'duduschka',
#  'BryceBealey',
#  'ZeleikaRobinson',
#  'kristal04416575',
#  'PassionateDave',
#  'OliviaQuim',
#  'NDoomster',
#  'janie_pb',
#  'EPisstaker',
#  'HennessyKesewa',
#  'MsFinalSay',
#  'MilitantlyA',
#  'PointlessBrexit',
#  'sylviadavis551',
#  'joelashbridge',
#  'LM_Marlow',
#  'wordfalcon',
#  '180_180_141',
#  'legalolder',
#  'chaplin_ray',
#  'RobVanderpere',
#  'BigG0dfrey',
#  'CarrollJackie99',
#  'GrantLewis1',
#  'TheLastPersont2',
#  'benjamincohen',
#  'Cat_n_Bagpipes',
#  'bob_euro',
#  'LindaLeather19',
#  'Pongo81575019',
#  'SwinsonBrian',
#  'grahphil',
#  '33mate33',
#  'cdeaker',
#  'Pongo81575019',
#  'KittyLaing',
#  'nicransome',
#  'Daniel252525',
#  'd_knotty',
#  'Paul_Crowson',
#  'StuartBudd1',
#  'DawnieR2',
#  'ASK_des',
#  'DrRiart',
#  'stevebrookstein',
#  'DylanBrownie1',
#  'VernonBriscoe',
#  'CharlieParish1',
#  'GilesMacDonogh',
#  'TrevorRudge1',
#  'craftybookworm']

# %%
dis=set()
for i in abusers:
    count=0
    for j in o2['screen_name']:
    
        if i==j:
           count+=1 
        if count==2:
            dis.add(j)
            print (count,j)
dis
# Out:
# 2 peterpalmer901
# 2 CarolineCreator
# 2 Hargraver
# 2 LeftLeftfooter
# 2 Pibasedlifeform
# 2 christill
# 2 MarkWelshpool
# 2 Patrick10599096
# 2 BSAboarding
# 2 harrisimo
# 2 guyevan29068996
# 2 harrisimo
# 2 StMichael888
# 2 LandanTownRyan
# 2 akazeeox
# 2 Mr_NG_Photo
# 2 AleexxJP
# 2 philiparrogers
# 2 Coops_tv
# 2 Jayphex303
# 2 mulsah1978
# 2 WxmJackoLa
# 2 BeatsSurrender
# 2 StuartDPlunkett
# 2 FrenchyStu
# 2 MCarrielies
# 2 MichaelKirkbri5
# 2 wardmajor
# 2 garymca66
# 2 mrneilmorrow
# 2 lilyk1000
# 2 Magman55
# 2 RtHonTwatness
# 2 namaste66ahimsa
# 2 Juliaarthur8
# 2 richiecarey35
# 2 Kat_Says_Stuff
# 2 stillbestest
# 2 BUDDHA_DRAGON1
# 2 ibrook1
# 2 PederDray
# 2 DilynThe
# 2 180_180_141
# 2 thetree_man
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 CarolineCreator
# 2 Hargraver
# 2 LeftLeftfooter
# 2 Pibasedlifeform
# 2 christill
# 2 MarkWelshpool
# 2 Patrick10599096
# 2 BSAboarding
# 2 harrisimo
# 2 guyevan29068996
# 2 harrisimo
# 2 StMichael888
# 2 LandanTownRyan
# 2 akazeeox
# 2 Mr_NG_Photo
# 2 AleexxJP
# 2 philiparrogers
# 2 Coops_tv
# 2 Jayphex303
# 2 mulsah1978
# 2 WxmJackoLa
# 2 BeatsSurrender
# 2 StuartDPlunkett
# 2 FrenchyStu
# 2 MCarrielies
# 2 MichaelKirkbri5
# 2 wardmajor
# 2 garymca66
# 2 mrneilmorrow
# 2 lilyk1000
# 2 Magman55
# 2 RtHonTwatness
# 2 namaste66ahimsa
# 2 Juliaarthur8
# 2 richiecarey35
# 2 Kat_Says_Stuff
# 2 stillbestest
# 2 BUDDHA_DRAGON1
# 2 ibrook1
# 2 PederDray
# 2 DilynThe
# 2 180_180_141
# 2 thetree_man
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 harrisimo
# 2 StMichael888
# 2 LandanTownRyan
# 2 akazeeox
# 2 Mr_NG_Photo
# 2 AleexxJP
# 2 philiparrogers
# 2 Coops_tv
# 2 Jayphex303
# 2 mulsah1978
# 2 WxmJackoLa
# 2 BeatsSurrender
# 2 StuartDPlunkett
# 2 FrenchyStu
# 2 MCarrielies
# 2 MichaelKirkbri5
# 2 wardmajor
# 2 garymca66
# 2 mrneilmorrow
# 2 lilyk1000
# 2 Magman55
# 2 RtHonTwatness
# 2 namaste66ahimsa
# 2 Juliaarthur8
# 2 richiecarey35
# 2 Kat_Says_Stuff
# 2 stillbestest
# 2 BUDDHA_DRAGON1
# 2 ibrook1
# 2 PederDray
# 2 DilynThe
# 2 180_180_141
# 2 thetree_man
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 harrisimo
# 2 StMichael888
# 2 LandanTownRyan
# 2 akazeeox
# 2 Mr_NG_Photo
# 2 AleexxJP
# 2 philiparrogers
# 2 Coops_tv
# 2 Jayphex303
# 2 mulsah1978
# 2 WxmJackoLa
# 2 BeatsSurrender
# 2 StuartDPlunkett
# 2 FrenchyStu
# 2 MCarrielies
# 2 MichaelKirkbri5
# 2 wardmajor
# 2 garymca66
# 2 mrneilmorrow
# 2 lilyk1000
# 2 Magman55
# 2 RtHonTwatness
# 2 namaste66ahimsa
# 2 Juliaarthur8
# 2 richiecarey35
# 2 Kat_Says_Stuff
# 2 stillbestest
# 2 BUDDHA_DRAGON1
# 2 ibrook1
# 2 PederDray
# 2 DilynThe
# 2 180_180_141
# 2 thetree_man
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 peterpalmer901
# 2 sarah_stook
# 2 DavidMagicsmith
# 2 TQGEssex
# 2 MCarrielies
# 2 stephentrew
# 2 the_middle_bit
# 2 duduschka
# 2 BryceBealey
# 2 ZeleikaRobinson
# 2 kristal04416575
# 2 PassionateDave
# 2 OliviaQuim
# 2 NDoomster
# 2 janie_pb
# 2 EPisstaker
# 2 HennessyKesewa
# 2 MsFinalSay
# 2 MilitantlyA
# 2 PointlessBrexit
# 2 sylviadavis551
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 peterpalmer901
# 2 CarolineCreator
# 2 Hargraver
# 2 LeftLeftfooter
# 2 Pibasedlifeform
# 2 christill
# 2 MarkWelshpool
# 2 Patrick10599096
# 2 BSAboarding
# 2 harrisimo
# 2 guyevan29068996
# 2 harrisimo
# 2 StMichael888
# 2 LandanTownRyan
# 2 akazeeox
# 2 Mr_NG_Photo
# 2 AleexxJP
# 2 philiparrogers
# 2 Coops_tv
# 2 Jayphex303
# 2 mulsah1978
# 2 WxmJackoLa
# 2 BeatsSurrender
# 2 StuartDPlunkett
# 2 FrenchyStu
# 2 MCarrielies
# 2 MichaelKirkbri5
# 2 wardmajor
# 2 garymca66
# 2 mrneilmorrow
# 2 lilyk1000
# 2 Magman55
# 2 RtHonTwatness
# 2 namaste66ahimsa
# 2 Juliaarthur8
# 2 richiecarey35
# 2 Kat_Says_Stuff
# 2 stillbestest
# 2 BUDDHA_DRAGON1
# 2 ibrook1
# 2 PederDray
# 2 DilynThe
# 2 180_180_141
# 2 thetree_man
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 MCarrielies
# 2 AnthonyStanbury
# 2 dontreallyuse79
# 2 orangeorangeboy
# 2 Lokster71
# 2 ffiniol14
# 2 PUPartyUK
# 2 Farrel_Raven
# 2 ely_peddler
# 2 IconoDesignUK
# 2 sallywilts
# 2 Nat__Wil
# 2 syerph
# 2 exasperated55
# 2 Wendysing
# 2 Athena6931
# 2 BridgeeCee
# 2 rorysalad
# 2 Juliaarthur8
# 2 matteusroberts
# 2 LadyZaichik
# 2 MsTropey
# 2 pipspeaker
# 2 cococupcakeice
# 2 CarolineCreator
# 2 TomHulme79
# 2 grahamlithgow
# 2 MCarrielies
# 2 _Harry_Brennan_
# 2 rosskcameron
# 2 mashleybrown
# 2 Annette1Hardy
# 2 MarianSwetman
# 2 Sportydoodle
# 2 lancastrian99
# 2 pchallinor
# 2 StuartWelsh4
# 2 Hayes3344
# 2 SuffolkCoastLab
# 2 DistilledWill
# 2 joelashbridge
# 2 GRALambo
# 2 poolton_portia
# 2 steve_hawkes
# 2 Michex69
# 2 LandanTownRyan
# 2 namaste66ahimsa
# 2 Youth4ia
# 2 Bobbiej90572948
# 2 Rock_1878
# 2 joelashbridge
# 2 LM_Marlow
# 2 wordfalcon
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 180_180_141
# 2 legalolder
# 2 chaplin_ray
# 2 RobVanderpere
# 2 BigG0dfrey
# 2 CarrollJackie99
# 2 GrantLewis1
# 2 TheLastPersont2
# 2 benjamincohen
# 2 Cat_n_Bagpipes
# 2 bob_euro
# 2 LindaLeather19
# 2 Pongo81575019
# 2 SwinsonBrian
# 2 grahphil
# 2 33mate33
# 2 cdeaker
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# 2 Pongo81575019
# 2 KittyLaing
# 2 nicransome
# 2 Daniel252525
# 2 d_knotty
# 2 Paul_Crowson
# 2 StuartBudd1
# 2 DawnieR2
# 2 ASK_des
# 2 DrRiart
# 2 stevebrookstein
# 2 DylanBrownie1
# 2 VernonBriscoe
# 2 CharlieParish1
# 2 GilesMacDonogh
# 2 TrevorRudge1
# 2 craftybookworm
# {'180_180_141',
#  '33mate33',
#  'ASK_des',
#  'AleexxJP',
#  'Annette1Hardy',
#  'AnthonyStanbury',
#  'Athena6931',
#  'BSAboarding',
#  'BUDDHA_DRAGON1',
#  'BeatsSurrender',
#  'BigG0dfrey',
#  'Bobbiej90572948',
#  'BridgeeCee',
#  'BryceBealey',
#  'CarolineCreator',
#  'CarrollJackie99',
#  'Cat_n_Bagpipes',
#  'CharlieParish1',
#  'Coops_tv',
#  'Daniel252525',
#  'DavidMagicsmith',
#  'DawnieR2',
#  'DilynThe',
#  'DistilledWill',
#  'DrRiart',
#  'DylanBrownie1',
#  'EPisstaker',
#  'Farrel_Raven',
#  'FrenchyStu',
#  'GRALambo',
#  'GilesMacDonogh',
#  'GrantLewis1',
#  'Hargraver',
#  'Hayes3344',
#  'HennessyKesewa',
#  'IconoDesignUK',
#  'Jayphex303',
#  'Juliaarthur8',
#  'Kat_Says_Stuff',
#  'KittyLaing',
#  'LM_Marlow',
#  'LadyZaichik',
#  'LandanTownRyan',
#  'LeftLeftfooter',
#  'LindaLeather19',
#  'Lokster71',
#  'MCarrielies',
#  'Magman55',
#  'MarianSwetman',
#  'MarkWelshpool',
#  'MichaelKirkbri5',
#  'Michex69',
#  'MilitantlyA',
#  'Mr_NG_Photo',
#  'MsFinalSay',
#  'MsTropey',
#  'NDoomster',
#  'Nat__Wil',
#  'OliviaQuim',
#  'PUPartyUK',
#  'PassionateDave',
#  'Patrick10599096',
#  'Paul_Crowson',
#  'PederDray',
#  'Pibasedlifeform',
#  'PointlessBrexit',
#  'Pongo81575019',
#  'RobVanderpere',
#  'Rock_1878',
#  'RtHonTwatness',
#  'Sportydoodle',
#  'StMichael888',
#  'StuartBudd1',
#  'StuartDPlunkett',
#  'StuartWelsh4',
#  'SuffolkCoastLab',
#  'SwinsonBrian',
#  'TQGEssex',
#  'TheLastPersont2',
#  'TomHulme79',
#  'TrevorRudge1',
#  'VernonBriscoe',
#  'Wendysing',
#  'WxmJackoLa',
#  'Youth4ia',
#  'ZeleikaRobinson',
#  '_Harry_Brennan_',
#  'akazeeox',
#  'benjamincohen',
#  'bob_euro',
#  'cdeaker',
#  'chaplin_ray',
#  'christill',
#  'cococupcakeice',
#  'craftybookworm',
#  'd_knotty',
#  'dontreallyuse79',
#  'duduschka',
#  'ely_peddler',
#  'exasperated55',
#  'ffiniol14',
#  'garymca66',
#  'grahamlithgow',
#  'grahphil',
#  'guyevan29068996',
#  'harrisimo',
#  'ibrook1',
#  'janie_pb',
#  'joelashbridge',
#  'kristal04416575',
#  'lancastrian99',
#  'legalolder',
#  'lilyk1000',
#  'mashleybrown',
#  'matteusroberts',
#  'mrneilmorrow',
#  'mulsah1978',
#  'namaste66ahimsa',
#  'nicransome',
#  'orangeorangeboy',
#  'pchallinor',
#  'peterpalmer901',
#  'philiparrogers',
#  'pipspeaker',
#  'poolton_portia',
#  'richiecarey35',
#  'rorysalad',
#  'rosskcameron',
#  'sallywilts',
#  'sarah_stook',
#  'stephentrew',
#  'steve_hawkes',
#  'stevebrookstein',
#  'stillbestest',
#  'syerph',
#  'sylviadavis551',
#  'the_middle_bit',
#  'thetree_man',
#  'wardmajor',
#  'wordfalcon'}

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 5               8             8               8            8         8
# 6              23            23              23           23        23
# 7              23            23              23           23        23
# 8              12            12              12           12        12
# 9              46            46              46           46        46
# 10             72            72              72           72        72
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 5            8         8          8          8                 8  ...
# 6           23        23         23         23                23  ...
# 7           23        23         23         23                23  ...
# 8           12        12         12         12                12  ...
# 9           46        46         46         46                46  ...
# 10          72        72         72         72                72  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 5             8          0      8         8        8           8            8
# 6            23          0     23        23       23          23           23
# 7            23          0     23        23       23          23           23
# 8            12          0     12        12       12          12           12
# 9            46          0     46        46       46          46           46
# 10           72          0     72        72       72          72           72
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 5                    4               8              8
# 6                    2              23             23
# 7                   18              23             23
# 8                    9              12             12
# 9                   18              46             46
# 10                  38              72             72
#
# [6 rows x 25 columns]

# %%
sum(o['classofspeech'])
# Out:
# 184

# %%
pero=[]
for i in o['classofspeech']:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero
# Out:
# [4.3478260869565215, 12.5, 12.5, 6.521739130434782, 25.0, 39.130434782608695]

# %%
xi=['May','June',"July",'August','September','October']

# %%
xi=['May','June',"July",'August','September','October']

#for i in pero.index:
   # xi.append(i)
yi=[]

for i in pero:
    yi.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yi, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of offensive speech',fontsize=20)
ax.set_title("Percentage of offensive speech in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
n=d1[d1['classofspeech']=='neither'].groupby('month',sort=True).count()
n
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  screen_name  username  \
# month
# 5             265           265             265          265       265
# 6             293           293             293          293       293
# 7             314           314             314          314       314
# 8             169           169             169          169       169
# 9             584           584             584          584       584
# 10            692           692             692          692       692
#
#        user_id  tweet_id  tweet_url  timestamp  timestamp_epochs  ...  \
# month                                                             ...
# 5          265       265        265        265               265  ...
# 6          293       293        293        293               293  ...
# 7          314       314        314        314               314  ...
# 8          169       169        169        169               169  ...
# 9          584       584        584        584               584  ...
# 10         692       692        692        692               692  ...
#
#        img_urls  video_url  likes  retweets  replies  is_replied  is_reply_to  \
# month
# 5           265          0    265       265      265         265          265
# 6           293          0    293       293      293         293          293
# 7           314          0    314       314      314         314          314
# 8           169          0    169       169      169         169          169
# 9           584          0    584       584      584         584          584
# 10          692          0    692       692      692         692          692
#
#        parent_tweet_id  reply_to_users  classofspeech
# month
# 5                  105             265            265
# 6                  102             293            293
# 7                  129             314            314
# 8                   93             169            169
# 9                  205             584            584
# 10                 271             692            692
#
# [6 rows x 25 columns]

# %%
pern=[]
for i in n['classofspeech']:
    ans=i*100/sum(n['classofspeech'])
    #print (ans)
    pern.append(ans)
pern
# Out:
# [11.437203280103581,
#  12.645662494605093,
#  13.552006905481226,
#  7.293914544669832,
#  25.20500647388865,
#  29.86620630125162]

# %%
xi=['May','June',"July",'August','September','October']

#for i in pero.index:
   # xi.append(i)
yn=[]

for i in pern:
    yn.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yn, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of tweets neither offensive nor hate',fontsize=20)
ax.set_title("Percentage of tweets neither offensive nor hate in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
x=[]

for i in o['classofspeech'].index:
    x.append(i)
y=[]

for i in o['classofspeech']:
    y.append(i)
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number of offensive words',fontsize=20)
ax.set_title("Number of offensive words in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
from textblob import TextBlob
x=d1['text']
senti=[]
for i in x:
    senti.append(TextBlob(i).sentiment[0])
    #print (TextBlob(i).sentiment[0])
d1['senscores']=senti    
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      screen_name  \
# 0              0          1703            1703      Rhiskiboi91
# 1              1          5449            5449         eliesian
# 2              2          5058            5058    Theatremusing
# 3              3          1149            1149     dianas_house
# 4              4           432             432     PennoftheNth
# ...          ...           ...             ...              ...
# 2496        2496          1113            1113  Chester66666666
# 2497        2497          3340            3340   oliviawood0706
# 2498        2498          1552            1552         Tonyhd16
# 2499        2499          5337            5337   craftybookworm
# 2500        2500          4668            4668  kathryninstereo
#
#                                                username              user_id  \
# 0     RÃÂÃÂ­an ÃÂÃÂ' Catharnaigh ÃÂ°ÃÂÃÂ...            333098431
# 1                                             Iain Lees   769802145726132224
# 2                                        Theatremusings   719706176649342977
# 3                                  Diane House Woodcock             22316199
# 4                                                 penny  1072947262781882368
# ...                                                 ...                  ...
# 2496                          ChesterCharlie6 Red #FBPE           1399929349
# 2497                                    hopeinthefuture           1853730362
# 2498                                             Tonyhd  1070714172726501377
# 2499                                Nicola ÃÂ¢ÃÂÃÂ             30026482
# 2500                                 Kathryn Cartwright             20906661
#
#                  tweet_id                                    tweet_url  \
# 0     1139278652401770496      /Rhiskiboi91/status/1139278652401770496
# 1     1174627552964546562         /eliesian/status/1174627552964546562
# 2     1154373272403927040    /Theatremusing/status/1154373272403927040
# 3     1123989924431257602     /dianas_house/status/1123989924431257602
# 4     1156793825567920128     /PennoftheNth/status/1156793825567920128
# ...                   ...                                          ...
# 2496  1125282960469630976  /Chester66666666/status/1125282960469630976
# 2497  1189662771228659712   /oliviawood0706/status/1189662771228659712
# 2498  1131232280905691136         /Tonyhd16/status/1131232280905691136
# 2499  1175890233046568960   /craftybookworm/status/1175890233046568960
# 2500  1180588812302348289  /kathryninstereo/status/1180588812302348289
#
#                 timestamp  timestamp_epochs  ... likes retweets replies  \
# 0     2019-06-13 21:09:32        1560460172  ...     2        0       0
# 1     2019-09-19 10:13:26        1568888006  ...     0        0       0
# 2     2019-07-25 12:50:10        1564059010  ...     0        0       0
# 3     2019-05-02 16:37:35        1556815055  ...     0        1       0
# 4     2019-08-01 05:08:34        1564636114  ...     0        0       0
# ...                   ...               ...  ...   ...      ...     ...
# 2496  2019-05-06 06:15:39        1557123339  ...     1        1       0
# 2497  2019-10-30 21:58:02        1572472682  ...     0        0       0
# 2498  2019-05-22 16:16:07        1558541767  ...     1        0       0
# 2499  2019-09-22 21:50:53        1569189053  ...     1        0       0
# 2500  2019-10-05 21:01:21        1570309281  ...     4        0       0
#
#      is_replied  is_reply_to parent_tweet_id  \
# 0         False         True    1.139135e+18
# 1         False        False             NaN
# 2         False        False             NaN
# 3         False        False             NaN
# 4         False        False             NaN
# ...         ...          ...             ...
# 2496      False         True    1.125045e+18
# 2497      False         True    1.189638e+18
# 2498      False         True    1.131231e+18
# 2499      False        False             NaN
# 2500      False        False             NaN
#
#                                          reply_to_users       classofspeech  \
# 0     [{'screen_name': 'ainefromderry', 'user_id': '...             neither
# 1                                                    []             neither
# 2                                                    []             neither
# 3                                                    []             neither
# 4                                                    []             neither
# ...                                                 ...                 ...
# 2496  [{'screen_name': 'lazaroumterror', 'user_id': ...             neither
# 2497  [{'screen_name': 'BrexitBetrayed', 'user_id': ...             neither
# 2498  [{'screen_name': 'bbclaurak', 'user_id': '6118...             neither
# 2499                                                 []  offensive_language
# 2500                                                 []             neither
#
#       month  senscores
# 0         6   0.467273
# 1         9   0.000000
# 2         7   0.000000
# 3         5   0.250000
# 4         8   0.000000
# ...     ...        ...
# 2496      5   0.000000
# 2497     10   0.100000
# 2498      5   0.000000
# 2499      9   0.033333
# 2500     10   0.000000
#
# [2501 rows x 27 columns]

# %%
len(d1)
# Out:
# 2501

# %%
b=d1.groupby('month',sort=True)['senscores'].mean()
b
# Out:
# month
# 5     0.041107
# 6     0.041990
# 7     0.058630
# 8     0.043275
# 9     0.065788
# 10    0.027533
# Name: senscores, dtype: float64

# %%
ys=[]

for i in b:
    ys.append(i)
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, ys,color='purple', marker='o', linestyle='dashed',linewidth=2, markersize=12)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores of six months',fontsize=20)
ax.set_title("Variation of sentimental scores",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
s = pd.Series(ys)
s=s*100
s
# Out:
# 0    4.110679
# 1    4.198996
# 2    5.863016
# 3    4.327539
# 4    6.578840
# 5    2.753329
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
ax.plot(xi, y,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of offensive tweets")
plt.plot('October',72, markersize=24,marker='X')
plt.yticks([-10,0,10,20,30,40,50,60,70])

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores*100 & number of offensive tweets',fontsize=17)
ax.set_title("Variation of mean sentiment scores of each month with offensive tweets for Nicky Morgan",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
ax.plot(xi, perh1,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Percentage of hate speech")

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Mean sentiment scores and % of hate speeches',fontsize=17)
ax.set_title("Variation of mean sentimental scores with % of hate speech for each month",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-333abb4f99be> in <module>
#       1 fig, ax = plt.subplots(figsize=(15,7))
#       2 ax.plot(xi, s,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mean sentimental score *100")#
# ----> 3 ax.plot(xi, perh1,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Percentage of hate speech")
#       4
#       5 ax.set_xlabel('Months',fontsize=20)
#
# NameError: name 'perh1' is not defined

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z

# %%
d1['classofspeech'].unique()

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z

# %%
o2=d1[d1['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o2

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o

# %%
sum(o['classofspeech'])

# %%
pero=[]
for i in o['classofspeech']:
    ans=i*100/sum(o['classofspeech'])
    #print (ans)
    pero.append(ans)
pero

# %%
xi=['February','March','April','May','June',"July",'August']

#for i in pero.index:
   # xi.append(i)
yi=[]

for i in pero:
    yi.append(i)
fig, ax = plt.subplots(figsize=(15,7))
plt.bar(xi, yi, edgecolor = 'black', linewidth=2)

ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Percentage of offensive speech',fontsize=20)
ax.set_title("Percentage of offensive speech in various months",fontsize=20)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")

ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#

ax.set_xlabel('Months',fontsize=20)
plt.plot('September',36.170212765957444, markersize=24,marker='X')
plt.plot('November',60, markersize=24,marker='X')

ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive words where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
pero

# %%
df=pd.read_csv("input2_threat_tom.csv")
df

# %%
o3=df[df['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o3

# %%
o33=df[df['classofspeech']=='hate_speech'].groupby('month',sort=True).count()
o33

# %%
sum(o3['classofspeech'])

# %%
pero3=[]
for i in o3['classofspeech']:
    ans=i*100/sum(o3['classofspeech'])
    #print (ans)
    pero3.append(ans)
pero3

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, pero,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Caroline Spelman")

ax.plot(x1, y1,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Mark Lancaster")#
ax.plot(x1, pero3,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Tom Watson")#

ax.set_xlabel('Months',fontsize=20)
plt.plot('September',36.170212765957444, markersize=24,marker='X')
plt.plot('November',60, markersize=24,marker='X')
plt.plot('November',20.73170731707317, markersize=24,marker='X')

ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive tweets where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
dff=pd.read_csv("input2_threat_Allen.csv")
dff

# %%
o4=dff[dff['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o4

# %%
sum(o3['classofspeech'])

# %%
pero4=[]
for i in o4['classofspeech']:
    ans=i*100/sum(o4['classofspeech'])
    #print (ans)
    pero4.append(ans)
pero4

# %%
peero4=[2.272727272727273,
 19.318181818181817,
 9.090909090909092,
 10.227272727272727,43.18181818181818,
 15.909090909090908]
x4=["September 2018",'October 2018','November 2018','December 2018','January 2018','February 2018']

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x4, peero4,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Heidi Allen")


ax.set_xlabel('Months',fontsize=20)

plt.plot('February',15.909090909090908, markersize=24,marker='X')
plt.yticks([0,10,20,30,40,50,60])
ax.set_ylabel('% of offensive words',fontsize=17)
ax.set_title("Variation in offensive words where X denotes refrain or resignation",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".5"})

d1=pd.read_csv("input2_threat.csv",encoding="latin1")
d1

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z

# %%
d1['classofspeech'].unique()

# %%
o=d1[d1['classofspeech']=='offensive_language'].groupby('month',sort=True).count()
o

# %%
sum(o['classofspeech'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee16fbac355f> in <module>
# ----> 1 sum(o['classofspeech'])
#
# NameError: name 'o' is not defined

# %%
import requests
x=d1['text']
no_neg=[]
no_pos=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/article_stats/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    if response.status_code==200:
      #print (jsonobj['number_negative_words'])
      no_neg.append(jsonobj['number_negative_words'])
      print (jsonobj['number_positive_words'])
      no_pos.append(jsonobj['number_positive_words'])
    else:     

      no_neg.append(0)
      #print (jsonobj['number_of_words'])
      no_pos.append(0)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in connect(self)
#     183     def connect(self):
# --> 184         conn = self._new_conn()
#     185         self._prepare_conn(conn)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000025FDBE6A548>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPConnectionPool(host='104.248.174.180', port=80): Max retries exceeded with url: /article_stats/?query=I'm%20glad%20she%20found%20the%20time%20to%20do%20one%20of%20BOJO!%20Aye%20of%20course%20with%20the%20new%20Wain%20and%20Wains%20when%20your%20good%20and%20ready%20%C3%83%C2%83%C3%82%C2%83%C3%83%C2%82%C3%82%C2%81ine!%20Also%20can%20i%20make%20a%20request%20ad%20Nicky%20Morgan%20to%20the%20list%20that%20would%20be%20hilarious%20also!%20 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000025FDBE6A548>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-397c5009f572> in <module>
#       4 no_pos=[]
#       5 for i in x:
# ----> 6     response=requests.get(f'http://104.248.174.180/article_stats/?query={i}')
#       7     #print(response.json())
#       8     jsonobj=response.json()
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='104.248.174.180', port=80): Max retries exceeded with url: /article_stats/?query=I'm%20glad%20she%20found%20the%20time%20to%20do%20one%20of%20BOJO!%20Aye%20of%20course%20with%20the%20new%20Wain%20and%20Wains%20when%20your%20good%20and%20ready%20%C3%83%C2%83%C3%82%C2%83%C3%83%C2%82%C3%82%C2%81ine!%20Also%20can%20i%20make%20a%20request%20ad%20Nicky%20Morgan%20to%20the%20list%20that%20would%20be%20hilarious%20also!%20 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000025FDBE6A548>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".6"})

df=pd.read_csv("negpos Nickymorgan.csv",encoding="latin1")
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0              0             0            1703              1703
# 1              1             1            5449              5449
# 2              2             2            5058              5058
# 3              3             3            1149              1149
# 4              4             4             432               432
# ...          ...           ...             ...               ...
# 2496        2496          2496            1113              1113
# 2497        2497          2497            3340              3340
# 2498        2498          2498            1552              1552
# 2499        2499          2499            5337              5337
# 2500        2500          2500            4668              4668
#
#           screen_name                                           username  \
# 0         Rhiskiboi91  RÃÂÃÂ­an ÃÂÃÂ' Catharnaigh ÃÂ°ÃÂÃÂ...
# 1            eliesian                                          Iain Lees
# 2       Theatremusing                                     Theatremusings
# 3        dianas_house                               Diane House Woodcock
# 4        PennoftheNth                                              penny
# ...               ...                                                ...
# 2496  Chester66666666                          ChesterCharlie6 Red #FBPE
# 2497   oliviawood0706                                    hopeinthefuture
# 2498         Tonyhd16                                             Tonyhd
# 2499   craftybookworm                                Nicola ÃÂ¢ÃÂÃÂ
# 2500  kathryninstereo                                 Kathryn Cartwright
#
#                   user_id             tweet_id  \
# 0               333098431  1139278652401770496
# 1      769802145726132224  1174627552964546562
# 2      719706176649342977  1154373272403927040
# 3                22316199  1123989924431257602
# 4     1072947262781882368  1156793825567920128
# ...                   ...                  ...
# 2496           1399929349  1125282960469630976
# 2497           1853730362  1189662771228659712
# 2498  1070714172726501377  1131232280905691136
# 2499             30026482  1175890233046568960
# 2500             20906661  1180588812302348289
#
#                                         tweet_url            timestamp  ...  \
# 0         /Rhiskiboi91/status/1139278652401770496  2019-06-13 21:09:32  ...
# 1            /eliesian/status/1174627552964546562  2019-09-19 10:13:26  ...
# 2       /Theatremusing/status/1154373272403927040  2019-07-25 12:50:10  ...
# 3        /dianas_house/status/1123989924431257602  2019-05-02 16:37:35  ...
# 4        /PennoftheNth/status/1156793825567920128  2019-08-01 05:08:34  ...
# ...                                           ...                  ...  ...
# 2496  /Chester66666666/status/1125282960469630976  2019-05-06 06:15:39  ...
# 2497   /oliviawood0706/status/1189662771228659712  2019-10-30 21:58:02  ...
# 2498         /Tonyhd16/status/1131232280905691136  2019-05-22 16:16:07  ...
# 2499   /craftybookworm/status/1175890233046568960  2019-09-22 21:50:53  ...
# 2500  /kathryninstereo/status/1180588812302348289  2019-10-05 21:01:21  ...
#
#       retweets replies is_replied is_reply_to parent_tweet_id  \
# 0            0       0      False        True    1.139135e+18
# 1            0       0      False       False             NaN
# 2            0       0      False       False             NaN
# 3            1       0      False       False             NaN
# 4            0       0      False       False             NaN
# ...        ...     ...        ...         ...             ...
# 2496         1       0      False        True    1.125045e+18
# 2497         0       0      False        True    1.189638e+18
# 2498         0       0      False        True    1.131231e+18
# 2499         0       0      False       False             NaN
# 2500         0       0      False       False             NaN
#
#                                          reply_to_users       classofspeech  \
# 0     [{'screen_name': 'ainefromderry', 'user_id': '...             neither
# 1                                                    []             neither
# 2                                                    []             neither
# 3                                                    []             neither
# 4                                                    []             neither
# ...                                                 ...                 ...
# 2496  [{'screen_name': 'lazaroumterror', 'user_id': ...             neither
# 2497  [{'screen_name': 'BrexitBetrayed', 'user_id': ...             neither
# 2498  [{'screen_name': 'bbclaurak', 'user_id': '6118...             neither
# 2499                                                 []  offensive_language
# 2500                                                 []             neither
#
#       month  negativewords  positivewords
# 0         6              0              5
# 1         9              0              0
# 2         7              0              0
# 3         5              0              1
# 4         8              0              0
# ...     ...            ...            ...
# 2496      5              0              0
# 2497     10              0              1
# 2498      5              0              0
# 2499      9              2              1
# 2500     10              0              0
#
# [2501 rows x 29 columns]

# %%
xi=['April','May','June','July','August','September']
kplus=df.groupby('month',sort=True)['positivewords'].sum()
plus=[]
for i in kplus:
    plus.append(i)
plus    
kneg=df.groupby('month',sort=True)['negativewords'].sum()
neg=[]
for i in kneg:
    neg.append(i)
    
neg
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, plus,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of positive words")#
ax.plot(xi, neg,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of negative words")
plt.yticks([50,100,150,200,250,300,350,400,450,500])
ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number of words in tweets',fontsize=17)
ax.set_title("Variation in number of negative and positive words in tweets for Nicky Morgan",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
o10=d1[d1['classofspeech']=='offensive_language']
o10
usertweets = o10.groupby('screen_name')
#Taking the top 25 tweeting users
top_users = usertweets.count()['text'].sort_values(ascending = False)[:25]
top_users_dict = top_users.to_dict()
user_ordered_dict =sorted(top_users_dict.items(), key=lambda x:x[1])
user_ordered_dict = user_ordered_dict[::-1]
#Now, like in the previous hashtags and mention cases, going to make #two lists, one with the username and one with the value
dict_values = []
dict_keys = []
for item in user_ordered_dict[0:25]:
    dict_keys.append(item[0])
    dict_values.append(item[1])
    fig = plt.figure(figsize = (15,7))
index = np.arange(25)
plt.bar(index, dict_values, edgecolor = 'black', linewidth=1)
plt.xlabel('Most active Users', fontsize = 18)
plt.yticks([0,1,2,3,4,5])
plt.ylabel('No of Tweets', fontsize=20)
plt.xticks(index,dict_keys, fontsize=15, rotation=80)
plt.title('Number of offensive tweets posted for Nicky Morgan', fontsize = 20)
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app

# %%
o2=d1[d1['classofspeech']=='offensive_language']
len(o2)
# Out:
# 184

# %%
oh=d1[d1['classofspeech']=='hate_speech']
len(oh)
# Out:
# 0

# %%
lab=[]
for i in range(len(df)):
    if df['negativewords'][i]>=df['positivewords'][i]:
        lab.append('n')
    else:
        lab.append('p')
lab   
df['speech']=lab
ol=df[df['speech']=='p'].groupby('month',sort=True).count()
ol
on=df[df['speech']=='n'].groupby('month',sort=True).count()
on
p=[]
for i in ol['positivewords']:
    p.append(i)
p    

n=[]
for i in on['positivewords']:
    n.append(i)
n
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, y,color='purple', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of offensive tweets")#

ax.plot(xi, p,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of positive tweets")#
ax.plot(xi, n,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of negative tweets")
plt.yticks([50,100,150,200,250,300,350,400,450,500])
ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number of words in tweets',fontsize=17)
ax.set_title("Variation in number of negative and positive tweets for Heidi Allen",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
hs=[0,0,0,0,0,0]

# %%
kplus=df.groupby('month',sort=True)['positivewords'].sum()
plus=[]
for i in kplus:
    plus.append(i)
plus    
kneg=df.groupby('month',sort=True)['negativewords'].sum()
neg=[]
for i in kneg:
    neg.append(i)
    
neg
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(xi, y,color='purple', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of offensive tweets")#
ax.plot(xi, hs,color='orange', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of hate speech tweets")#

ax.plot(xi, plus,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of positive tweets")#
ax.plot(xi, neg,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of negative tweets")
plt.yticks([0,50,100,150,200,250,300,350,400,450,500])
ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number of tweets',fontsize=17)
ax.set_title("Variation in number of negative, hate speech, offensive and positive tweets for Nicky Morgan",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".5"})

d1=pd.read_csv("nickymorgan_stance.csv",encoding="latin1")
d1
# Out:
#      Unnamed: 0  date          name  \
# 0             0    10  Nicky Morgan
# 1             1    10  Nicky Morgan
# 2             2    10  Nicky Morgan
# 3             3    10  Nicky Morgan
# 4             4    10  Nicky Morgan
# ..          ...   ...           ...
# 408         408     5  Nicky Morgan
# 409         409     5  Nicky Morgan
# 410         410     5  Nicky Morgan
# 411         411     5  Nicky Morgan
# 412         412     5  Nicky Morgan
#
#                                                  tweet        stance
# 0    And it has always been a huge pleasure to work...          stay
# 1    Thank you Tony - a huge pleasure to work with ...          stay
# 2                                           Thank you!    irrelevant
# 3    For the first time in 18 years I won't be a ca...         leave
# 4    Very pleased to see this happen https://twitte...          stay
# ..                                                 ...           ...
# 408  Donât let the showers put you off voting tod...         leave
# 409  Lots of campaign day activity going on in Loug...  no sentiment
# 410  Polls are open today 7am - 10pm - #VoteConserv...  no sentiment
# 411  Kind; thank you but the excellent Rory Stewart...          stay
# 412  Good article from @mysouthfields on why @Conse...         leave
#
# [413 rows x 5 columns]

# %%
leave=d1[d1['stance']=='leave']
leave
# Out:
#      Unnamed: 0  date          name  \
# 3             3    10  Nicky Morgan
# 7             7    10  Nicky Morgan
# 9             9    10  Nicky Morgan
# 10           10    10  Nicky Morgan
# 13           13    10  Nicky Morgan
# ..          ...   ...           ...
# 393         393     5  Nicky Morgan
# 394         394     5  Nicky Morgan
# 401         401     5  Nicky Morgan
# 408         408     5  Nicky Morgan
# 412         412     5  Nicky Morgan
#
#                                                  tweet stance
# 3    For the first time in 18 years I won't be a ca...  leave
# 7    Good luck with the book - a privilege to be in...  leave
# 9    Amazing! Massive congratulations @EnglandRugby...  leave
# 10   How we are working to ensure better mobile con...  leave
# 13   Delighted to announce today a further Â£12 mil...  leave
# ..                                                 ...    ...
# 393  Clockwise Credit Union have been championing o...  leave
# 394  Too many women face horrific abuse online and ...  leave
# 401  Abiding message from doorsteps is âsort Brex...  leave
# 408  Donât let the showers put you off voting tod...  leave
# 412  Good article from @mysouthfields on why @Conse...  leave
#
# [120 rows x 5 columns]

# %%
stay=d1[d1['stance']=='stay']
stay
# Out:
#      Unnamed: 0  date          name  \
# 0             0    10  Nicky Morgan
# 1             1    10  Nicky Morgan
# 4             4    10  Nicky Morgan
# 12           12    10  Nicky Morgan
# 24           24    10  Nicky Morgan
# 31           31    10  Nicky Morgan
# 33           33    10  Nicky Morgan
# 40           40    10  Nicky Morgan
# 44           44    10  Nicky Morgan
# 61           61    10  Nicky Morgan
# 62           62    10  Nicky Morgan
# 83           83     9  Nicky Morgan
# 94           94     9  Nicky Morgan
# 110         110     9  Nicky Morgan
# 116         116     9  Nicky Morgan
# 119         119     9  Nicky Morgan
# 121         121     9  Nicky Morgan
# 122         122     9  Nicky Morgan
# 141         141     8  Nicky Morgan
# 150         150     8  Nicky Morgan
# 151         151     8  Nicky Morgan
# 152         152     8  Nicky Morgan
# 165         165     7  Nicky Morgan
# 166         166     7  Nicky Morgan
# 174         174     7  Nicky Morgan
# 191         191     7  Nicky Morgan
# 201         201     7  Nicky Morgan
# 205         205     7  Nicky Morgan
# 213         213     7  Nicky Morgan
# 229         229     6  Nicky Morgan
# 238         238     6  Nicky Morgan
# 239         239     6  Nicky Morgan
# 241         241     6  Nicky Morgan
# 245         245     6  Nicky Morgan
# 250         250     6  Nicky Morgan
# 282         282     6  Nicky Morgan
# 283         283     6  Nicky Morgan
# 289         289     6  Nicky Morgan
# 297         297     6  Nicky Morgan
# 304         304     6  Nicky Morgan
# 309         309     6  Nicky Morgan
# 315         315     6  Nicky Morgan
# 326         326     5  Nicky Morgan
# 330         330     5  Nicky Morgan
# 340         340     5  Nicky Morgan
# 342         342     5  Nicky Morgan
# 351         351     5  Nicky Morgan
# 355         355     5  Nicky Morgan
# 358         358     5  Nicky Morgan
# 359         359     5  Nicky Morgan
# 366         366     5  Nicky Morgan
# 373         373     5  Nicky Morgan
# 375         375     5  Nicky Morgan
# 383         383     5  Nicky Morgan
# 385         385     5  Nicky Morgan
# 396         396     5  Nicky Morgan
# 411         411     5  Nicky Morgan
#
#                                                  tweet stance
# 0    And it has always been a huge pleasure to work...   stay
# 1    Thank you Tony - a huge pleasure to work with ...   stay
# 4    Very pleased to see this happen https://twitte...   stay
# 12   #Loughborough has been announced as one of the...   stay
# 24   Thanks for your support - you had a more produ...   stay
# 31   Many congratulations - this is terrific news @...   stay
# 33                       Thank you for the invitation!   stay
# 40   A pleasure to see you all. Thank you for the u...   stay
# 44   Let's get Brexit done so we can focus on recru...   stay
# 61   Great to welcome so many students interested i...   stay
# 62                               Very nice to meet you   stay
# 83   The biggest peacetime repatriation in history ...   stay
# 94   Thank you @Women2Win for a very useful bag wit...   stay
# 110  Many congratulations - pleasure to be here for...   stay
# 116  Really excellent to see todayâs announcement...   stay
# 119  Delighted to see you in #Loughborough @Rupert_...   stay
# 121  Excellent news that #Loughborough is one of 10...   stay
# 122  A great pleasure to visit & to meet you all - ...   stay
# 141  A very happy birthday to Loughborough based @S...   stay
# 150                         Many congratulations! ð   stay
# 151  Calling all small shops in the Loughborough co...   stay
# 152  This would be 'short-term' in the same way Lab...   stay
# 165                        It was great and thank you!   stay
# 166  So very sorry to hear about Pete's death - he ...   stay
# 174  Ah, thank you. Itâs been a delight & thank y...   stay
# 191                              Glad they enjoyed it!   stay
# 201  Thank you @BorisJohnson for your reply https:/...   stay
# 205                                      Thank you Ben   stay
# 213  If you arenât a constituent then Iâm afrai...   stay
# 229  This is an important and interesting thread ht...   stay
# 238         Very fair point Ally - will chase - again!   stay
# 239  Thank you for the support! https://twitter.com...   stay
# 241  Except Iâm not a Minister & Iâm not based ...   stay
# 245  Thank you for joining us https://twitter.com/R...   stay
# 250  Suspect efforts to manipulate the final two wi...   stay
# 282      I have a bit of explaining to do on Monday..!   stay
# 283  I fear whatever I say here will upset someone ...   stay
# 289  Pleasure to visit @HancocksSweets in Loughboro...   stay
# 297  Baobab Cafe on Market St will hold a 'cake and...   stay
# 304  Delighted to be one of the contributors to thi...   stay
# 309  #Loughborough is a sea of pink as @CR_UK Race ...   stay
# 315  Delighted to welcome pupils from Hall Orchard,...   stay
# 326  Loughborough Town of Sanctuary is holding a co...   stay
# 330  Thank you @cathynewman for the excellent âBl...   stay
# 340  Why Brexit has changed the job of an MP for ev...   stay
# 342                                   Happy to oblige!   stay
# 351  Australia deserve to win for sheer bravery on ...   stay
# 355  France showing Iceland how making a political ...   stay
# 358                                             Quite!   stay
# 359               Follow that Estonia! #eurovision2019   stay
# 366  So, one of the Norwegian singers is apparently...   stay
# 373  The man from Russia seems to be stuck in his s...   stay
# 375  Czech Republic entry demonstrating how free mo...   stay
# 383  Delighted to join you all https://twitter.com/...   stay
# 385  It's #NationalNumeracyDay today and I'm workin...   stay
# 396  Thank you for your support https://twitter.com...   stay
# 411  Kind; thank you but the excellent Rory Stewart...   stay

# %%
L=leave.groupby('date',sort=True)['stance'].count()
L
# Out:
# date
# 5     26
# 6     31
# 7     13
# 8     10
# 9     20
# 10    20
# Name: stance, dtype: int64

# %%
months=['May','June','July','August','September','October']

# %%
lea=[]
for i in L:
    print (i)
    lea.append(i)
lea
# Out:
# 26
# 31
# 13
# 10
# 20
# 20
# [26, 31, 13, 10, 20, 20]

# %%
S=stay.groupby('date',sort=True)['stance'].count()
S
# Out:
# date
# 5     15
# 6     13
# 7      7
# 8      4
# 9      7
# 10    11
# Name: stance, dtype: int64

# %%
sta=[]
for i in S:
    sta.append(i)
    print (i)
sta
# Out:
# 15
# 13
# 7
# 4
# 7
# 11
# [15, 13, 7, 4, 7, 11]

# %%
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(months, lea,color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Leave")#
ax.plot(months, sta,color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Stay")
ax.set_xlabel('Months',fontsize=20)
ax.set_ylabel('Number',fontsize=17)
ax.set_title("Variation in stance for Nicky Morgan",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})

ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
